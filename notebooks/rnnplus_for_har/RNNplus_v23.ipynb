# %% [markdown]
# <div class="alert" style="background-color:#BBA14F; color:white; padding:0px 10px; border-radius:5px;">
#     <h1 style='margin:15px 15px; color:#000000; font-size:32px'><b>New Recurrent Network (best23)</b></h1>
#         <h2 style='margin:15px 15px; color:#000000; font-size:24px'>Human Activity Recognition Problem</h2>
# </div>
#
# The work is under the **"Master Thesis"** by **Chau Tran** with the supervision from **Prof. Roland Olsson**.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.python.util.tf_export import keras_export
from tensorflow.keras.backend import eval

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, RobustScaler, StandardScaler

import tensorboard
import keras
from keras.utils import tf_utils
import pandas as pd #pd.plotting.register_matplotlib_converters
import numpy as np
import sys, os, math, time, datetime, re

print("tf: ", tf.__version__)
print("tb: ", tensorboard.__version__)
print(os.getcwd())

RANDOM_SEED = 42
ISMOORE_DATASETS = True
timestep = 40
tf.random.set_seed(np.random.seed(RANDOM_SEED))
tf.get_logger().setLevel('ERROR')
tf.autograph.set_verbosity(1)
tf.config.set_visible_devices([], 'GPU')
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '1'

snapshot = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
path = '../../../../Datasets/6_har/0_WISDM/WISDM_ar_v1.1/WISDM_ar_v1.1_processed/WISDM_ar_v1.1_wt_overlap'
# Debugging with Tensorboard
logdir="logs/fit/rnn_v1_1/" + snapshot
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
# tf.debugging.experimental.enable_dump_debug_info(logdir, tensor_debug_mode="FULL_HEALTH", circular_buffer_size=-1)

with open("../../params/params_har.txt") as f:
    hyperparams = dict([re.sub('['+' ,\n'+']','',x.replace(' .', '')).split('=') for x in f][1:-1])
hyperparams = dict([k, float(v)] for k, v in hyperparams.items())
hyperparams['testSize'] = 0.500
hyperparams['noUnits'] = 81
hyperparams['timestep'] = 40
print(hyperparams)

def seperateValues(data, noInput, noOutput, isMoore=True):
    x_data, y_data = None, None
    for i in range(data.shape[0]):
        if isMoore:
            x_data_i = data[i].reshape(-1, noInput+noOutput)
            x_data_i, y_data_i = x_data_i[:, 0:noInput], x_data_i[-1, noInput:]
        else:
            x_data_i = data[i][:-1].reshape(-1, noInput)
            y_data_i = data[i][-1].reshape(-1, noOutput)
        x_data = x_data_i[np.newaxis,:,:] if x_data is None else np.append(x_data, x_data_i[np.newaxis,:,:], axis=0)
        y_data = y_data_i.reshape(1, -1) if y_data is None else np.append(y_data, y_data_i.reshape(1, -1), axis=0)
    return x_data, y_data

def fromBit_v0( b ) :
    return -0.9 if b == 0.0 else 0.9

def fromBit_v1( b ) :
    return 0 if b == 0.0 else 1

def isCorrect( target, actual ) :
    y1 = False if target < 0.0 else True
    y2 = False if actual < 0.0 else True
    return y1 == y2 

class CustomMetricError(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name='custom_metric_error', dtype=None, threshold=0.5):
        super(CustomMetricError, self).__init__(
            customMetricfn_tensor, name, dtype=dtype, threshold=threshold)

    def customMetricfn_tensor(true, pred, threshold=0.5):
        true = tf.convert_to_tensor(true)
        pred = tf.convert_to_tensor(pred)
        threshold = tf.cast(threshold, pred.dtype)
        pred = tf.cast(pred >= threshold, pred.dtype)
        true = tf.cast(true >= threshold, true.dtype)
        return keras.backend.mean(tf.equal(true, pred), axis=-1)

def customMetricfn(y_true, y_pred):
    numCorrect = 0
    for i in range( y_true.shape[0] ) :
        for j in range( y_pred.shape[ 1 ] ) :
            if isCorrect( y_true[ i, j ], y_pred[ i, j ] ) :
                numCorrect += 1
    return (numCorrect/(y_pred.shape[1]*y_true.shape[0]))

def indexOfMax( xs ) :
    m, k = xs[ 0 ], 0
    for i in range( 0, xs.size ) :
        if xs[ i ] > m :
            m = xs[ i ]
            k = i
    return k

def customMetricfn_full(y_true, y_pred):
    numCorrect = 0
    for i in range(y_pred.shape[0]) :
        if indexOfMax(y_pred[i]) == indexOfMax(y_val[i]) :
            numCorrect += 1
    return numCorrect/y_pred.shape[0]
            
def srelu(x):
    return tf.keras.backend.clip(x, -1, 1)

def _generate_zero_filled_state_for_cell(cell, inputs, batch_size, dtype):
    if inputs is not None:
        batch_size = tf.shape(inputs)[0]
        dtype = inputs.dtype
    return _generate_zero_filled_state(batch_size, cell.state_size, dtype)

def _generate_zero_filled_state(batch_size_tensor, state_size, dtype):
    def create_zeros(unnested_state_size):
        flat_dims = tf.TensorShape(unnested_state_size).as_list()
        init_state_size = [batch_size_tensor] + flat_dims
        return tf.zeros(init_state_size, dtype=dtype)
    
    if batch_size_tensor is None or dtype is None:
        raise ValueError(
            'batch_size and dtype cannot be None while constructing initial state. '
            f'Received: batch_size={batch_size_tensor}, dtype={dtype}')

    return tf.nest.map_structure(create_zeros, state_size)  if tf.nest.is_nested(state_size) else create_zeros(state_size)

class RNN_plus_v1_cell(tf.keras.layers.LSTMCell):
    def __init__(self, units, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', bias_initializer='zeros', dropout=0., recurrent_dropout=0., use_bias=True, **kwargs):
        if units < 0:
            raise ValueError(f'Received an invalid value for argument `units`, '
                                f'expected a positive integer, got {units}.')
        # By default use cached variable under v2 mode, see b/143699808.
        if tf.compat.v1.executing_eagerly_outside_functions():
            self._enable_caching_device = kwargs.pop('enable_caching_device', True)
        else:
            self._enable_caching_device = kwargs.pop('enable_caching_device', False)
        super(RNN_plus_v1_cell, self).__init__(units, **kwargs)
        self.units = units
        self.state_size = self.units
        self.output_size = self.units
        
        self.kernel_initializer = tf.keras.initializers.get(kernel_initializer)
        self.recurrent_initializer = tf.keras.initializers.get(recurrent_initializer)
        self.aux_initializer = tf.keras.initializers.get('zeros')
        self.bias_initializer = tf.keras.initializers.get(bias_initializer)
        
        self.dropout = min(1., max(0., dropout))
        self.recurrent_dropout = min(1., max(0., recurrent_dropout))
        self.state_size = [self.units, self.units, self.units]
        self.output_size = self.units
        self.use_bias = True
    
    def build(self, input_shape):
        input_dim = input_shape[-1]
        self.kernel = self.add_weight(shape=(input_dim, self.units), name='w_input', initializer=self.kernel_initializer, regularizer=None, constraint=None)
        self.recurrent_kernel = self.add_weight(shape=(self.units, self.units*2), name='w_otherpeeps', initializer=self.recurrent_initializer, regularizer=None, constraint=None)
        self.aux_kernel  = self.add_weight(shape=(1, self.units), name='w_aux', initializer=self.recurrent_initializer, regularizer=None, constraint=None)
        self.bias = self.add_weight( shape=(self.units,), name='b', initializer=self.bias_initializer, regularizer=None, constraint=None) if self.use_bias else None
        self.built = True
        
    def call(self, inputs, states, training=None):
        state0, state1, prev_output = states[0], states[1], states[2]
        
        w_in_0 = self.kernel

        w_op0, w_op1 = tf.split(self.recurrent_kernel, num_or_size_splits=2, axis=1)
        w_op0 = tf.linalg.set_diag(w_op0, np.zeros((self.units,), dtype=int))
        w_op1 = tf.linalg.set_diag(w_op1, np.zeros((self.units,), dtype=int))
        
        w_aux = self.aux_kernel
        
        inputs_0 = tf.keras.backend.dot(inputs, w_in_0)
        if self.bias is not None:
            inputs_0 = tf.keras.backend.bias_add(inputs_0, self.bias)
            
        op0 = tf.keras.backend.dot(state0, w_op0)
        op1 = tf.keras.backend.dot(state0, w_op1)
        
        z  = tf.nn.relu(w_aux[0]*op0 + inputs_0) - state1
        output = srelu(state0*state0 + prev_output)

        return output, [z, op1, output]
    
    def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
        return list(_generate_zero_filled_state_for_cell(self, inputs, batch_size, dtype))

class LearningRateLoggingCallback(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        print("Learning Rate: ", self.model.optimizer.learning_rate.lr)
    
    def on_epoch_end(self, epoch, logs=None):
        tf.summary.scalar('learning rate', self.model.optimizer.learning_rate.lr, step=epoch)

class customLRSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, batchSize, initialLearningRate, learningRateDecay, decayDurationFactor, numTrainingSteps, glorotScaleFactor=0.1, orthogonalScaleFactor=0.1, name=None):
        self.batchSize = batchSize
        self.initialLearningRate = initialLearningRate
        self.learningRateDecay = learningRateDecay
        self.decayDurationFactor = decayDurationFactor
        self.glorotScaleFactor = glorotScaleFactor
        self.orthogonalScaleFactor = orthogonalScaleFactor
        self.numTrainingSteps = numTrainingSteps
        self.name = name
        self.T = tf.constant(self.decayDurationFactor * (self.numTrainingSteps/self.batchSize), dtype=tf.float32, name="T")
        self.lr = self.initialLearningRate
    
    def __call__(self, step):
        self.t = tf.cast(step, tf.float32)
        self.lr = tf.cond(self.t > self.T, 
                           lambda: tf.constant(self.learningRateDecay * self.initialLearningRate, dtype=tf.float32),
                           lambda: self.initialLearningRate - (1.0 - self.learningRateDecay) * self.initialLearningRate * self.t / self.T
                          )
        return self.lr
    
    def get_config(self):
        return {
            "initial_learning_rate": self.initialLearningRate,
            "decay_rate": self.learningRateDecay,
            "name": self.name
        }
    
def rnn_plus_model(noInput, noOutput, timestep):
    """Builds a recurrent model."""
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.RNN(cell=RNN_plus_v1_cell(units=hyperparams['noUnits']), input_shape=[timestep, noInput], unroll=False, name='RNNp_layer'))
    model.add(tf.keras.layers.Dense(noInput+noOutput, activation='tanh', name='MLP_layer'))
    model.add(tf.keras.layers.Dense(noOutput))
    optimizer = tf.keras.optimizers.Adam(learning_rate=customLRSchedule(hyperparams['batchSize'], hyperparams['initialLearningRate'], hyperparams['learningRateDecay'], hyperparams['decayDurationFactor'], hyperparams['numTrainingSteps']), \
                                        beta_1=hyperparams['beta1'], beta_2=hyperparams['beta2'], epsilon=hyperparams['epsilon'], amsgrad=False, name="tunedAdam")
    model.compile(optimizer=optimizer, loss = 'mse', run_eagerly=False)
    return model
# Out:
# tf:  2.7.0
# tb:  2.7.0
# C:\Users\chaut\OneDrive - Heriot-Watt University\HIOF_Master\Master_Thesis\NewLSTM\Codes\tf_implementations\notebooks\rnnplus_for_har
# {'batchSize': 4.0, 'numTrainingSteps': 320000.0, 'beta1': 0.974833, 'beta2': 0.99689, 'epsilon': 0.00388, 'decayDurationFactor': 0.979079, 'initialLearningRate': 0.002798, 'learningRateDecay': 0.001025, 'glorotScaleFactor': 0.1, 'orthogonalScaleFactor': 0.1, 'testSize': 0.5, 'noUnits': 81, 'timestep': 40}

# %%
# print('Step 1: Dividing the training and testing set with ratio 1:1 (50%).')
# df_train = np.array(pd.read_csv(os.path.join(path,'wisdm.ni=3.no=6.ts=40.os=40.spit=50.train.csv'), skiprows=1))
# df_val = np.array(pd.read_csv(os.path.join(path,'wisdm.ni=3.no=6.ts=40.os=40.spit=50.val.csv'), skiprows=1))
# print(df_train.shape, df_val.shape)

# with open(os.path.join(path,'wisdm.ni=3.no=6.ts=40.os=40.spit=50.train.csv'), "r") as fp:
#     [noIn, noOut] = [int(x) for x in fp.readline().replace('\n', '').split(',')]
        
# print('Step 2: Separating values and labels.')
# x_train, y_train = seperateValues(df_train, noIn, noOut, isMoore=ISMOORE_DATASETS)
# x_val, y_val = seperateValues(df_val, noIn, noOut, isMoore=ISMOORE_DATASETS)
# scaler = StandardScaler()
# x_train = (scaler.fit_transform(x_train.reshape(x_train.shape[0], -1))).reshape(x_train.shape[0], hyperparams['timestep'], noIn)
# x_val = (scaler.fit_transform(x_val.reshape(x_val.shape[0], -1))).reshape(x_val.shape[0], hyperparams['timestep'], noIn)
# for i in range( y_train.shape[ 0 ] ) :
#     for j in range( y_train.shape[ 1 ] ) :
#         y_train[ i, j ] = fromBit( y_train[ i, j ] )

# for i in range( y_val.shape[ 0 ] ) :
#     for j in range( y_val.shape[ 1 ] ) :
#         y_val[ i, j ] = fromBit( y_val[ i, j ] )

# print("+ Training set:   ", x_train.shape, y_train.shape, x_train.dtype)
# print("+ Validating set: ", x_val.shape, y_val.shape, x_val.dtype)

# model = rnn_plus_model(noIn, noOut, timestep=hyperparams['timestep'])
# model_history = model.fit(
#                     x_train, y_train,
#                     batch_size=int(hyperparams['batchSize']),
#                     verbose=0, # Suppress chatty output; use Tensorboard instead
#                     # epochs=10,
#                     epochs=int(hyperparams['numTrainingSteps']/(x_train.shape[0])),
#                     validation_data=(x_val, y_val),
#                     shuffle=True,
#                     use_multiprocessing=False,
#                     callbacks=[tensorboard_callback]
#                 )
# y_pred = model.predict(x_val, verbose=1, batch_size=int(hyperparams['batchSize']))

# val_performance = model.evaluate(x_val, y_val, batch_size=int(hyperparams['batchSize']), verbose=0)
# y_pred = model.predict(x_val, verbose=0)

# print( f"Val_performance = {val_performance}")
# print( f"Val_accuracy = {round(customMetricfn_full(y_val, y_pred), 5)}")

# %%
# print('Step 1: Dividing the training and testing set with ratio 1:1 (50%).')
# df_train = np.array(pd.read_csv(os.path.join(path,'wisdm.ni=3.no=6.ts=40.os=40.spit=0.all.shuffled.train.csv'), skiprows=0))
# df_val = np.array(pd.read_csv(os.path.join(path,'wisdm.ni=3.no=6.ts=40.os=40.spit=0.all.shuffled.test.csv'), skiprows=0))

# print(df_train.shape, df_val.shape)

# noIn, noOut = 3, 6

# print('Step 2: Separating values and labels.')
# x_train, y_train = seperateValues(df_train, noIn, noOut, isMoore=ISMOORE_DATASETS)
# x_val, y_val = seperateValues(df_val, noIn, noOut, isMoore=ISMOORE_DATASETS)
# scaler = StandardScaler()
# x_train = (scaler.fit_transform(x_train.reshape(x_train.shape[0], -1))).reshape(x_train.shape[0], hyperparams['timestep'], noIn)
# x_val = (scaler.fit_transform(x_val.reshape(x_val.shape[0], -1))).reshape(x_val.shape[0], hyperparams['timestep'], noIn)
# for i in range( y_train.shape[ 0 ] ) :
#     for j in range( y_train.shape[ 1 ] ) :
#         y_train[ i, j ] = fromBit( y_train[ i, j ] )

# for i in range( y_val.shape[ 0 ] ) :
#     for j in range( y_val.shape[ 1 ] ) :
#         y_val[ i, j ] = fromBit( y_val[ i, j ] )

# print("+ Training set:   ", x_train.shape, y_train.shape, x_train.dtype)
# print("+ Validating set: ", x_val.shape, y_val.shape, x_val.dtype)

# model = rnn_plus_model(noIn, noOut, timestep=hyperparams['timestep'])
# model_history = model.fit(
#                     x_train, y_train,
#                     batch_size=int(hyperparams['batchSize']),
#                     verbose=0, # Suppress chatty output; use Tensorboard instead
#                     # epochs=10,
#                     epochs=int(hyperparams['numTrainingSteps']/(x_train.shape[0])),
#                     validation_data=(x_val, y_val),
#                     shuffle=True,
#                     use_multiprocessing=False,
#                     callbacks=[tensorboard_callback]
#                 )
# y_pred = model.predict(x_val, verbose=0, batch_size=int(hyperparams['batchSize']))

# val_performance = model.evaluate(x_val, y_val, batch_size=int(hyperparams['batchSize']), verbose=0)
# y_pred = model.predict(x_val, verbose=0)

# print(f"Val_performance = {val_performance}")
# print(f"Val_accuracy = {round(customMetricfn_full(y_val, y_pred), 5)}")

# %%
if __name__ == '__main__':
    ISMOORE_DATASETS = True
    noIn, noOut = 3, 6
    path = '..//..//..//..//Datasets//6_har//0_WISDM//WISDM_ar_v1.1//wisdm_script_and_data//wisdm_script_and_data//WISDM//testdata'
    fileslist = [f for f in sorted(os.listdir(path)) if os.path.isfile(os.path.join(path, f))]
    logdir = f"./logs/scalars/wisdm"
    tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
    print(hyperparams)
    for file_no in range(8):
        trainFile = f'train{file_no}.csv'
        valFile   = f'val{file_no}.csv'
        df_train  = np.array(pd.read_csv(os.path.join(path, trainFile), skiprows=1))
        df_val    = np.array(pd.read_csv(os.path.join(path, valFile), skiprows=1))

        scaler    = StandardScaler()
        x_train, y_train = seperateValues(df_train, noIn, noOut, isMoore=ISMOORE_DATASETS)
        x_val,   y_val   = seperateValues(df_val,   noIn, noOut, isMoore=ISMOORE_DATASETS) 
        display(x_train.shape)
        x_train   = (scaler.fit_transform(x_train.reshape(x_train.shape[0], -1))).reshape(x_train.shape[0], hyperparams['timestep'], noIn)
        x_val     = (scaler.fit_transform(x_val.reshape(x_val.shape[0], -1))).reshape(x_val.shape[0], hyperparams['timestep'], noIn)
        for i in range( y_train.shape[ 0 ]) :
            for j in range( y_train.shape[1]) :
                y_train[i, j] = fromBit_v1(y_train[i,j])
        for i in range(y_val.shape[0]):
            for j in range(y_val.shape[ 1 ]):
                y_val[i, j] = fromBit_v1(y_val[ i, j ])
        
        model = rnn_plus_model(noIn, noOut, timestep=hyperparams['timestep'])
        model_history = model.fit(
                            x_train, y_train,
                            batch_size=int(hyperparams['batchSize']),
                            verbose=1, # Suppress chatty output; use Tensorboard instead
                            epochs=int(hyperparams['numTrainingSteps']/(x_train.shape[0])),
                            validation_data=(x_val, y_val),
                            shuffle=True,
                            use_multiprocessing=False,
                            callbacks=[tensorboard_callback, LearningRateLoggingCallback()],
                        )
        y_pred = model.predict(x_val, verbose=0, batch_size=int(hyperparams['batchSize']))
        val_performance = model.evaluate(x_val, y_val, batch_size=int(hyperparams['batchSize']), verbose=0)
        print(f"{valFile} val_performance = {val_performance}")
        print(f"{valFile} val accuracy = {round(customMetricfn_full(y_val, y_pred), 5)}")
# Out:
# {'batchSize': 4.0, 'numTrainingSteps': 320000.0, 'beta1': 0.974833, 'beta2': 0.99689, 'epsilon': 0.00388, 'decayDurationFactor': 0.979079, 'initialLearningRate': 0.002798, 'learningRateDecay': 0.001025, 'glorotScaleFactor': 0.1, 'orthogonalScaleFactor': 0.1, 'testSize': 0.5, 'noUnits': 81, 'timestep': 40}
# (13769, 40, 3)
# Learning Rate:  0.002798
# Epoch 1/23
# 3443/3443 [==============================] - 39s 11ms/step - loss: 0.0498 - val_loss: 0.0384
# Learning Rate:  tf.Tensor(0.002675134, shape=(), dtype=float32)
# Epoch 2/23
# 3443/3443 [==============================] - 43s 12ms/step - loss: 0.0266 - val_loss: 0.0254
# Learning Rate:  tf.Tensor(0.0025522679, shape=(), dtype=float32)
# Epoch 3/23
# 3443/3443 [==============================] - 44s 13ms/step - loss: 0.0219 - val_loss: 0.0209
# Learning Rate:  tf.Tensor(0.002429402, shape=(), dtype=float32)
# Epoch 4/23
# 3443/3443 [==============================] - 45s 13ms/step - loss: 0.0190 - val_loss: 0.0201
# Learning Rate:  tf.Tensor(0.0023065358, shape=(), dtype=float32)
# Epoch 5/23
# 3443/3443 [==============================] - 46s 13ms/step - loss: 0.0168 - val_loss: 0.0206
# Learning Rate:  tf.Tensor(0.00218367, shape=(), dtype=float32)
# Epoch 6/23
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0150 - val_loss: 0.0167
# Learning Rate:  tf.Tensor(0.002060804, shape=(), dtype=float32)
# Epoch 7/23
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0142 - val_loss: 0.0149
# Learning Rate:  tf.Tensor(0.001937938, shape=(), dtype=float32)
# Epoch 8/23
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0126 - val_loss: 0.0153
# Learning Rate:  tf.Tensor(0.001815072, shape=(), dtype=float32)
# Epoch 9/23
# 3443/3443 [==============================] - 53s 15ms/step - loss: 0.0117 - val_loss: 0.0142
# Learning Rate:  tf.Tensor(0.001692206, shape=(), dtype=float32)
# Epoch 10/23
# 3443/3443 [==============================] - 52s 15ms/step - loss: 0.0105 - val_loss: 0.0144
# Learning Rate:  tf.Tensor(0.0015693401, shape=(), dtype=float32)
# Epoch 11/23
# 3443/3443 [==============================] - 51s 15ms/step - loss: 0.0099 - val_loss: 0.0136
# Learning Rate:  tf.Tensor(0.0014464741, shape=(), dtype=float32)
# Epoch 12/23
# 3443/3443 [==============================] - 51s 15ms/step - loss: 0.0086 - val_loss: 0.0113
# Learning Rate:  tf.Tensor(0.0013236081, shape=(), dtype=float32)
# Epoch 13/23
# 3443/3443 [==============================] - 51s 15ms/step - loss: 0.0078 - val_loss: 0.0122
# Learning Rate:  tf.Tensor(0.0012007422, shape=(), dtype=float32)
# Epoch 14/23
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0070 - val_loss: 0.0116
# Learning Rate:  tf.Tensor(0.0010778762, shape=(), dtype=float32)
# Epoch 15/23
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0062 - val_loss: 0.0106
# Learning Rate:  tf.Tensor(0.0009550102, shape=(), dtype=float32)
# Epoch 16/23
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0053 - val_loss: 0.0099
# Learning Rate:  tf.Tensor(0.0008321442, shape=(), dtype=float32)
# Epoch 17/23
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0047 - val_loss: 0.0089
# Learning Rate:  tf.Tensor(0.0007092783, shape=(), dtype=float32)
# Epoch 18/23
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0041 - val_loss: 0.0086
# Learning Rate:  tf.Tensor(0.00058641215, shape=(), dtype=float32)
# Epoch 19/23
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0034 - val_loss: 0.0085
# Learning Rate:  tf.Tensor(0.0004635465, shape=(), dtype=float32)
# Epoch 20/23
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0029 - val_loss: 0.0080
# Learning Rate:  tf.Tensor(0.00034068036, shape=(), dtype=float32)
# Epoch 21/23
# 3443/3443 [==============================] - 52s 15ms/step - loss: 0.0025 - val_loss: 0.0078
# Learning Rate:  tf.Tensor(0.00021781446, shape=(), dtype=float32)
# Epoch 22/23
# 3443/3443 [==============================] - 51s 15ms/step - loss: 0.0022 - val_loss: 0.0078
# Learning Rate:  tf.Tensor(9.494834e-05, shape=(), dtype=float32)
# Epoch 23/23
# 3443/3443 [==============================] - 51s 15ms/step - loss: 0.0020 - val_loss: 0.0077
# val0.csv val_performance = 0.007747558876872063
# val0.csv val accuracy = 0.97131
# (13769, 40, 3)
# Learning Rate:  0.002798
# Epoch 1/23
# 3443/3443 [==============================] - 50s 14ms/step - loss: 0.0479 - val_loss: 0.0282
# Learning Rate:  tf.Tensor(0.002675134, shape=(), dtype=float32)
# Epoch 2/23
# 3443/3443 [==============================] - 52s 15ms/step - loss: 0.0281 - val_loss: 0.0244
# Learning Rate:  tf.Tensor(0.0025522679, shape=(), dtype=float32)
# Epoch 3/23
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0224 - val_loss: 0.0206
# Learning Rate:  tf.Tensor(0.002429402, shape=(), dtype=float32)
# Epoch 4/23
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0198 - val_loss: 0.0196
# Learning Rate:  tf.Tensor(0.0023065358, shape=(), dtype=float32)
# Epoch 5/23
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0177 - val_loss: 0.0156
# Learning Rate:  tf.Tensor(0.00218367, shape=(), dtype=float32)
# Epoch 6/23
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0156 - val_loss: 0.0147
# Learning Rate:  tf.Tensor(0.002060804, shape=(), dtype=float32)
# Epoch 7/23
# 3443/3443 [==============================] - 50s 15ms/step - loss: 0.0139 - val_loss: 0.0158
# Learning Rate:  tf.Tensor(0.001937938, shape=(), dtype=float32)
# Epoch 8/23
# 3443/3443 [==============================] - 50s 15ms/step - loss: 0.0126 - val_loss: 0.0125
# Learning Rate:  tf.Tensor(0.001815072, shape=(), dtype=float32)
# Epoch 9/23
# 3443/3443 [==============================] - 51s 15ms/step - loss: 0.0116 - val_loss: 0.0154
# Learning Rate:  tf.Tensor(0.001692206, shape=(), dtype=float32)
# Epoch 10/23
# 3443/3443 [==============================] - 56s 16ms/step - loss: 0.0104 - val_loss: 0.0110
# Learning Rate:  tf.Tensor(0.0015693401, shape=(), dtype=float32)
# Epoch 11/23
# 3443/3443 [==============================] - 57s 17ms/step - loss: 0.0094 - val_loss: 0.0112
# Learning Rate:  tf.Tensor(0.0014464741, shape=(), dtype=float32)
# Epoch 12/23
# 3443/3443 [==============================] - 53s 15ms/step - loss: 0.0083 - val_loss: 0.0105
# Learning Rate:  tf.Tensor(0.0013236081, shape=(), dtype=float32)
# Epoch 13/23
# 3443/3443 [==============================] - 50s 14ms/step - loss: 0.0073 - val_loss: 0.0100
# Learning Rate:  tf.Tensor(0.0012007422, shape=(), dtype=float32)
# Epoch 14/23
# 1375/3443 [==========>...................] - ETA: 24s - loss: 0.0065

# %%
ISMOORE_DATASETS = True
noIn, noOut = 3, 6
path = '..//..//pythons//wisdm_script_and_data//wisdm_script_and_data//WISDM//wisdm_ar_v1.1_wt_overlap'
fileslist = [f for f in sorted(os.listdir(path)) if os.path.isfile(os.path.join(path, f))]
logdir = f"./logs/scalars/wisdm"
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
print(hyperparams)
for file_no in range(8):
    trainFile = f'train{file_no}.csv'
    valFile   = f'val{file_no}.csv'
    df_train  = np.array(pd.read_csv(os.path.join(path, trainFile), skiprows=1))
    df_val    = np.array(pd.read_csv(os.path.join(path, valFile), skiprows=1))
    
    scaler    = StandardScaler()
    x_train, y_train = seperateValues(df_train, noIn, noOut, isMoore=ISMOORE_DATASETS)
    x_val,   y_val   = seperateValues(df_val,   noIn, noOut, isMoore=ISMOORE_DATASETS) 
    x_train   = (scaler.fit_transform(x_train.reshape(x_train.shape[0], -1))).reshape(x_train.shape[0], hyperparams['timestep'], noIn)
    x_val     = (scaler.fit_transform(x_val.reshape(x_val.shape[0], -1))).reshape(x_val.shape[0], hyperparams['timestep'], noIn)
    for i in range( y_train.shape[ 0 ]) :
        for j in range( y_train.shape[1]) :
            y_train[i, j] = fromBit_v0(y_train[i,j])
    for i in range(y_val.shape[0]):
        for j in range(y_val.shape[ 1 ]):
            y_val[i, j] = fromBit_v0(y_val[ i, j ])

    model = rnn_plus_model(noIn, noOut, timestep=hyperparams['timestep'])
    model_history = model.fit(
                        x_train, y_train,
                        batch_size=int(hyperparams['batchSize']),
                        verbose=1, # Suppress chatty output; use Tensorboard instead
                        epochs=int(hyperparams['numTrainingSteps']/(x_train.shape[0])),
                        validation_data=(x_val, y_val),
                        shuffle=True,
                        use_multiprocessing=False,
                        callbacks=[tensorboard_callback, LearningRateLoggingCallback()],
                    )
    y_pred = model.predict(x_val, verbose=0, batch_size=int(hyperparams['batchSize']))
    val_performance = model.evaluate(x_val, y_val, batch_size=int(hyperparams['batchSize']), verbose=0)
    print(f"{valFile} val_performance = {val_performance}")
    print(f"{valFile} val accuracy = {round(customMetricfn_full(y_val, y_pred), 5)}")
# Out:
# {'batchSize': 4.0, 'numTrainingSteps': 320000.0, 'beta1': 0.974833, 'beta2': 0.99689, 'epsilon': 0.00388, 'decayDurationFactor': 0.979079, 'initialLearningRate': 0.002798, 'learningRateDecay': 0.001025, 'glorotScaleFactor': 0.1, 'orthogonalScaleFactor': 0.1, 'testSize': 0.5, 'noUnits': 81, 'timestep': 40}
# Learning Rate:  0.002798
# Epoch 1/23
# 3443/3443 [==============================] - 151s 43ms/step - loss: 0.1408 - val_loss: 0.1026
# Learning Rate:  tf.Tensor(0.002675134, shape=(), dtype=float32)
# Epoch 2/23
# 3443/3443 [==============================] - 126s 37ms/step - loss: 0.0779 - val_loss: 0.0952
# Learning Rate:  tf.Tensor(0.0025522679, shape=(), dtype=float32)
# Epoch 3/23
# 3443/3443 [==============================] - 117s 34ms/step - loss: 0.0680 - val_loss: 0.0759
# Learning Rate:  tf.Tensor(0.002429402, shape=(), dtype=float32)
# Epoch 4/23
# 3443/3443 [==============================] - 119s 34ms/step - loss: 0.0586 - val_loss: 0.0588
# Learning Rate:  tf.Tensor(0.0023065358, shape=(), dtype=float32)
# Epoch 5/23
# 3443/3443 [==============================] - 117s 34ms/step - loss: 0.0543 - val_loss: 0.0680
# Learning Rate:  tf.Tensor(0.00218367, shape=(), dtype=float32)
# Epoch 6/23
# 3443/3443 [==============================] - 117s 34ms/step - loss: 0.0522 - val_loss: 0.0533
# Learning Rate:  tf.Tensor(0.002060804, shape=(), dtype=float32)
# Epoch 7/23
# 3443/3443 [==============================] - 124s 36ms/step - loss: 0.0509 - val_loss: 0.0665
# Learning Rate:  tf.Tensor(0.001937938, shape=(), dtype=float32)
# Epoch 8/23
# 3443/3443 [==============================] - 117s 34ms/step - loss: 0.0457 - val_loss: 0.0616
# Learning Rate:  tf.Tensor(0.001815072, shape=(), dtype=float32)
# Epoch 9/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0435 - val_loss: 0.0598
# Learning Rate:  tf.Tensor(0.001692206, shape=(), dtype=float32)
# Epoch 10/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0437 - val_loss: 0.0496
# Learning Rate:  tf.Tensor(0.0015693401, shape=(), dtype=float32)
# Epoch 11/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0372 - val_loss: 0.0564
# Learning Rate:  tf.Tensor(0.0014464741, shape=(), dtype=float32)
# Epoch 12/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0388 - val_loss: 0.0561
# Learning Rate:  tf.Tensor(0.0013236081, shape=(), dtype=float32)
# Epoch 13/23
# 3443/3443 [==============================] - 124s 36ms/step - loss: 0.0348 - val_loss: 0.0522
# Learning Rate:  tf.Tensor(0.0012007422, shape=(), dtype=float32)
# Epoch 14/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0333 - val_loss: 0.0448
# Learning Rate:  tf.Tensor(0.0010778762, shape=(), dtype=float32)
# Epoch 15/23
# 3443/3443 [==============================] - 114s 33ms/step - loss: 0.0308 - val_loss: 0.0447
# Learning Rate:  tf.Tensor(0.0009550102, shape=(), dtype=float32)
# Epoch 16/23
# 3443/3443 [==============================] - 114s 33ms/step - loss: 0.0277 - val_loss: 0.0426
# Learning Rate:  tf.Tensor(0.0008321442, shape=(), dtype=float32)
# Epoch 17/23
# 3443/3443 [==============================] - 114s 33ms/step - loss: 0.0266 - val_loss: 0.0465
# Learning Rate:  tf.Tensor(0.0007092783, shape=(), dtype=float32)
# Epoch 18/23
# 3443/3443 [==============================] - 115s 33ms/step - loss: 0.0231 - val_loss: 0.0417
# Learning Rate:  tf.Tensor(0.00058641215, shape=(), dtype=float32)
# Epoch 19/23
# 3443/3443 [==============================] - 114s 33ms/step - loss: 0.0208 - val_loss: 0.0393
# Learning Rate:  tf.Tensor(0.0004635465, shape=(), dtype=float32)
# Epoch 20/23
# 3443/3443 [==============================] - 114s 33ms/step - loss: 0.0189 - val_loss: 0.0390
# Learning Rate:  tf.Tensor(0.00034068036, shape=(), dtype=float32)
# Epoch 21/23
# 3443/3443 [==============================] - 114s 33ms/step - loss: 0.0165 - val_loss: 0.0388
# Learning Rate:  tf.Tensor(0.00021781446, shape=(), dtype=float32)
# Epoch 22/23
# 3443/3443 [==============================] - 114s 33ms/step - loss: 0.0150 - val_loss: 0.0373
# Learning Rate:  tf.Tensor(9.494834e-05, shape=(), dtype=float32)
# Epoch 23/23
# 3443/3443 [==============================] - 114s 33ms/step - loss: 0.0141 - val_loss: 0.0377
# val0.csv val_performance = 0.0377097986638546
# val0.csv val accuracy = 0.96194
# Learning Rate:  0.002798
# Epoch 1/23
# 3443/3443 [==============================] - 125s 35ms/step - loss: 0.1349 - val_loss: 0.0809
# Learning Rate:  tf.Tensor(0.002675134, shape=(), dtype=float32)
# Epoch 2/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0722 - val_loss: 0.0700
# Learning Rate:  tf.Tensor(0.0025522679, shape=(), dtype=float32)
# Epoch 3/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0616 - val_loss: 0.0602
# Learning Rate:  tf.Tensor(0.002429402, shape=(), dtype=float32)
# Epoch 4/23
# 3443/3443 [==============================] - 123s 36ms/step - loss: 0.0537 - val_loss: 0.0539
# Learning Rate:  tf.Tensor(0.0023065358, shape=(), dtype=float32)
# Epoch 5/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0537 - val_loss: 0.0534
# Learning Rate:  tf.Tensor(0.00218367, shape=(), dtype=float32)
# Epoch 6/23
# 3443/3443 [==============================] - 126s 37ms/step - loss: 0.0488 - val_loss: 0.0506
# Learning Rate:  tf.Tensor(0.002060804, shape=(), dtype=float32)
# Epoch 7/23
# 3443/3443 [==============================] - 126s 37ms/step - loss: 0.0451 - val_loss: 0.0578
# Learning Rate:  tf.Tensor(0.001937938, shape=(), dtype=float32)
# Epoch 8/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0429 - val_loss: 0.0462
# Learning Rate:  tf.Tensor(0.001815072, shape=(), dtype=float32)
# Epoch 9/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0412 - val_loss: 0.0463
# Learning Rate:  tf.Tensor(0.001692206, shape=(), dtype=float32)
# Epoch 10/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0401 - val_loss: 0.0443
# Learning Rate:  tf.Tensor(0.0015693401, shape=(), dtype=float32)
# Epoch 11/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0391 - val_loss: 0.0488
# Learning Rate:  tf.Tensor(0.0014464741, shape=(), dtype=float32)
# Epoch 12/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0338 - val_loss: 0.0433
# Learning Rate:  tf.Tensor(0.0013236081, shape=(), dtype=float32)
# Epoch 13/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0336 - val_loss: 0.0418
# Learning Rate:  tf.Tensor(0.0012007422, shape=(), dtype=float32)
# Epoch 14/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0301 - val_loss: 0.0367
# Learning Rate:  tf.Tensor(0.0010778762, shape=(), dtype=float32)
# Epoch 15/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0264 - val_loss: 0.0355
# Learning Rate:  tf.Tensor(0.0009550102, shape=(), dtype=float32)
# Epoch 16/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0245 - val_loss: 0.0337
# Learning Rate:  tf.Tensor(0.0008321442, shape=(), dtype=float32)
# Epoch 17/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0222 - val_loss: 0.0366
# Learning Rate:  tf.Tensor(0.0007092783, shape=(), dtype=float32)
# Epoch 18/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0182 - val_loss: 0.0347
# Learning Rate:  tf.Tensor(0.00058641215, shape=(), dtype=float32)
# Epoch 19/23
# 3443/3443 [==============================] - 122s 36ms/step - loss: 0.0166 - val_loss: 0.0314
# Learning Rate:  tf.Tensor(0.0004635465, shape=(), dtype=float32)
# Epoch 20/23
# 3443/3443 [==============================] - 122s 36ms/step - loss: 0.0142 - val_loss: 0.0313
# Learning Rate:  tf.Tensor(0.00034068036, shape=(), dtype=float32)
# Epoch 21/23
# 3443/3443 [==============================] - 122s 36ms/step - loss: 0.0131 - val_loss: 0.0302
# Learning Rate:  tf.Tensor(0.00021781446, shape=(), dtype=float32)
# Epoch 22/23
# 3443/3443 [==============================] - 123s 36ms/step - loss: 0.0121 - val_loss: 0.0301
# Learning Rate:  tf.Tensor(9.494834e-05, shape=(), dtype=float32)
# Epoch 23/23
# 3443/3443 [==============================] - 123s 36ms/step - loss: 0.0115 - val_loss: 0.0301
# val1.csv val_performance = 0.03012826293706894
# val1.csv val accuracy = 0.9703
# Learning Rate:  0.002798
# Epoch 1/23
# 3443/3443 [==============================] - 124s 36ms/step - loss: 0.1412 - val_loss: 0.0896
# Learning Rate:  tf.Tensor(0.002675134, shape=(), dtype=float32)
# Epoch 2/23
# 3443/3443 [==============================] - 122s 36ms/step - loss: 0.0719 - val_loss: 0.0669
# Learning Rate:  tf.Tensor(0.0025522679, shape=(), dtype=float32)
# Epoch 3/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0575 - val_loss: 0.0549
# Learning Rate:  tf.Tensor(0.002429402, shape=(), dtype=float32)
# Epoch 4/23
# 3443/3443 [==============================] - 112s 33ms/step - loss: 0.0539 - val_loss: 0.0550
# Learning Rate:  tf.Tensor(0.0023065358, shape=(), dtype=float32)
# Epoch 5/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0473 - val_loss: 0.0492
# Learning Rate:  tf.Tensor(0.00218367, shape=(), dtype=float32)
# Epoch 6/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0430 - val_loss: 0.0473
# Learning Rate:  tf.Tensor(0.002060804, shape=(), dtype=float32)
# Epoch 7/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0425 - val_loss: 0.0444
# Learning Rate:  tf.Tensor(0.001937938, shape=(), dtype=float32)
# Epoch 8/23
# 3443/3443 [==============================] - 112s 33ms/step - loss: 0.0399 - val_loss: 0.0399
# Learning Rate:  tf.Tensor(0.001815072, shape=(), dtype=float32)
# Epoch 9/23
# 3443/3443 [==============================] - 114s 33ms/step - loss: 0.0353 - val_loss: 0.0433
# Learning Rate:  tf.Tensor(0.001692206, shape=(), dtype=float32)
# Epoch 10/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0333 - val_loss: 0.0352
# Learning Rate:  tf.Tensor(0.0015693401, shape=(), dtype=float32)
# Epoch 11/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0298 - val_loss: 0.0386
# Learning Rate:  tf.Tensor(0.0014464741, shape=(), dtype=float32)
# Epoch 12/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0277 - val_loss: 0.0379
# Learning Rate:  tf.Tensor(0.0013236081, shape=(), dtype=float32)
# Epoch 13/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0238 - val_loss: 0.0364
# Learning Rate:  tf.Tensor(0.0012007422, shape=(), dtype=float32)
# Epoch 14/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0223 - val_loss: 0.0332
# Learning Rate:  tf.Tensor(0.0010778762, shape=(), dtype=float32)
# Epoch 15/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0199 - val_loss: 0.0301
# Learning Rate:  tf.Tensor(0.0009550102, shape=(), dtype=float32)
# Epoch 16/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0167 - val_loss: 0.0283
# Learning Rate:  tf.Tensor(0.0008321442, shape=(), dtype=float32)
# Epoch 17/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0142 - val_loss: 0.0278
# Learning Rate:  tf.Tensor(0.0007092783, shape=(), dtype=float32)
# Epoch 18/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0130 - val_loss: 0.0253
# Learning Rate:  tf.Tensor(0.00058641215, shape=(), dtype=float32)
# Epoch 19/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0115 - val_loss: 0.0259
# Learning Rate:  tf.Tensor(0.0004635465, shape=(), dtype=float32)
# Epoch 20/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0093 - val_loss: 0.0267
# Learning Rate:  tf.Tensor(0.00034068036, shape=(), dtype=float32)
# Epoch 21/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0082 - val_loss: 0.0249
# Learning Rate:  tf.Tensor(0.00021781446, shape=(), dtype=float32)
# Epoch 22/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0076 - val_loss: 0.0242
# Learning Rate:  tf.Tensor(9.494834e-05, shape=(), dtype=float32)
# Epoch 23/23
# 3443/3443 [==============================] - 111s 32ms/step - loss: 0.0072 - val_loss: 0.0243
# val2.csv val_performance = 0.024342158809304237
# val2.csv val accuracy = 0.97059
# Learning Rate:  0.002798
# Epoch 1/23
# 3443/3443 [==============================] - 128s 36ms/step - loss: 0.1474 - val_loss: 0.0894
# Learning Rate:  tf.Tensor(0.002675134, shape=(), dtype=float32)
# Epoch 2/23
# 3443/3443 [==============================] - 120s 35ms/step - loss: 0.0722 - val_loss: 0.0790
# Learning Rate:  tf.Tensor(0.0025522679, shape=(), dtype=float32)
# Epoch 3/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0580 - val_loss: 0.0619
# Learning Rate:  tf.Tensor(0.002429402, shape=(), dtype=float32)
# Epoch 4/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0499 - val_loss: 0.0739
# Learning Rate:  tf.Tensor(0.0023065358, shape=(), dtype=float32)
# Epoch 5/23
# 3443/3443 [==============================] - 112s 33ms/step - loss: 0.0447 - val_loss: 0.0489
# Learning Rate:  tf.Tensor(0.00218367, shape=(), dtype=float32)
# Epoch 6/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0415 - val_loss: 0.0460
# Learning Rate:  tf.Tensor(0.002060804, shape=(), dtype=float32)
# Epoch 7/23
# 3443/3443 [==============================] - 112s 33ms/step - loss: 0.0379 - val_loss: 0.0472
# Learning Rate:  tf.Tensor(0.001937938, shape=(), dtype=float32)
# Epoch 8/23
# 3443/3443 [==============================] - 116s 34ms/step - loss: 0.0361 - val_loss: 0.0445
# Learning Rate:  tf.Tensor(0.001815072, shape=(), dtype=float32)
# Epoch 9/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0349 - val_loss: 0.0482
# Learning Rate:  tf.Tensor(0.001692206, shape=(), dtype=float32)
# Epoch 10/23
# 3443/3443 [==============================] - 112s 33ms/step - loss: 0.0300 - val_loss: 0.0464
# Learning Rate:  tf.Tensor(0.0015693401, shape=(), dtype=float32)
# Epoch 11/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0279 - val_loss: 0.0382
# Learning Rate:  tf.Tensor(0.0014464741, shape=(), dtype=float32)
# Epoch 12/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0235 - val_loss: 0.0405
# Learning Rate:  tf.Tensor(0.0013236081, shape=(), dtype=float32)
# Epoch 13/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0221 - val_loss: 0.0365
# Learning Rate:  tf.Tensor(0.0012007422, shape=(), dtype=float32)
# Epoch 14/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0192 - val_loss: 0.0424
# Learning Rate:  tf.Tensor(0.0010778762, shape=(), dtype=float32)
# Epoch 15/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0165 - val_loss: 0.0386
# Learning Rate:  tf.Tensor(0.0009550102, shape=(), dtype=float32)
# Epoch 16/23
# 3443/3443 [==============================] - 114s 33ms/step - loss: 0.0147 - val_loss: 0.0331
# Learning Rate:  tf.Tensor(0.0008321442, shape=(), dtype=float32)
# Epoch 17/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0120 - val_loss: 0.0313
# Learning Rate:  tf.Tensor(0.0007092783, shape=(), dtype=float32)
# Epoch 18/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0107 - val_loss: 0.0309
# Learning Rate:  tf.Tensor(0.00058641215, shape=(), dtype=float32)
# Epoch 19/23
# 3443/3443 [==============================] - 116s 34ms/step - loss: 0.0092 - val_loss: 0.0296
# Learning Rate:  tf.Tensor(0.0004635465, shape=(), dtype=float32)
# Epoch 20/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0082 - val_loss: 0.0316
# Learning Rate:  tf.Tensor(0.00034068036, shape=(), dtype=float32)
# Epoch 21/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0075 - val_loss: 0.0307
# Learning Rate:  tf.Tensor(0.00021781446, shape=(), dtype=float32)
# Epoch 22/23
# 3443/3443 [==============================] - 113s 33ms/step - loss: 0.0069 - val_loss: 0.0299
# Learning Rate:  tf.Tensor(9.494834e-05, shape=(), dtype=float32)
# Epoch 23/23
# 3443/3443 [==============================] - 123s 36ms/step - loss: 0.0066 - val_loss: 0.0298
# val3.csv val_performance = 0.02978174388408661
# val3.csv val accuracy = 0.96848
# Learning Rate:  0.002798
# Epoch 1/23
# 3443/3443 [==============================] - 120s 34ms/step - loss: 0.1365 - val_loss: 0.0760
# Learning Rate:  tf.Tensor(0.002675134, shape=(), dtype=float32)
# Epoch 2/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0723 - val_loss: 0.0549
# Learning Rate:  tf.Tensor(0.0025522679, shape=(), dtype=float32)
# Epoch 3/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0585 - val_loss: 0.0496
# Learning Rate:  tf.Tensor(0.002429402, shape=(), dtype=float32)
# Epoch 4/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0530 - val_loss: 0.0685
# Learning Rate:  tf.Tensor(0.0023065358, shape=(), dtype=float32)
# Epoch 5/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0482 - val_loss: 0.0430
# Learning Rate:  tf.Tensor(0.00218367, shape=(), dtype=float32)
# Epoch 6/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0426 - val_loss: 0.0396
# Learning Rate:  tf.Tensor(0.002060804, shape=(), dtype=float32)
# Epoch 7/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0391 - val_loss: 0.0405
# Learning Rate:  tf.Tensor(0.001937938, shape=(), dtype=float32)
# Epoch 8/23
# 3443/3443 [==============================] - 119s 34ms/step - loss: 0.0371 - val_loss: 0.0418
# Learning Rate:  tf.Tensor(0.001815072, shape=(), dtype=float32)
# Epoch 9/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0329 - val_loss: 0.0383
# Learning Rate:  tf.Tensor(0.001692206, shape=(), dtype=float32)
# Epoch 10/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0300 - val_loss: 0.0423
# Learning Rate:  tf.Tensor(0.0015693401, shape=(), dtype=float32)
# Epoch 11/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0284 - val_loss: 0.0346
# Learning Rate:  tf.Tensor(0.0014464741, shape=(), dtype=float32)
# Epoch 12/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0241 - val_loss: 0.0372
# Learning Rate:  tf.Tensor(0.0013236081, shape=(), dtype=float32)
# Epoch 13/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0228 - val_loss: 0.0371
# Learning Rate:  tf.Tensor(0.0012007422, shape=(), dtype=float32)
# Epoch 14/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0194 - val_loss: 0.0301
# Learning Rate:  tf.Tensor(0.0010778762, shape=(), dtype=float32)
# Epoch 15/23
# 3443/3443 [==============================] - 119s 35ms/step - loss: 0.0164 - val_loss: 0.0397
# Learning Rate:  tf.Tensor(0.0009550102, shape=(), dtype=float32)
# Epoch 16/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0143 - val_loss: 0.0274
# Learning Rate:  tf.Tensor(0.0008321442, shape=(), dtype=float32)
# Epoch 17/23
# 3443/3443 [==============================] - 119s 35ms/step - loss: 0.0126 - val_loss: 0.0271
# Learning Rate:  tf.Tensor(0.0007092783, shape=(), dtype=float32)
# Epoch 18/23
# 3443/3443 [==============================] - 119s 34ms/step - loss: 0.0102 - val_loss: 0.0256
# Learning Rate:  tf.Tensor(0.00058641215, shape=(), dtype=float32)
# Epoch 19/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0086 - val_loss: 0.0252
# Learning Rate:  tf.Tensor(0.0004635465, shape=(), dtype=float32)
# Epoch 20/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0067 - val_loss: 0.0243
# Learning Rate:  tf.Tensor(0.00034068036, shape=(), dtype=float32)
# Epoch 21/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0059 - val_loss: 0.0246
# Learning Rate:  tf.Tensor(0.00021781446, shape=(), dtype=float32)
# Epoch 22/23
# 3443/3443 [==============================] - 118s 34ms/step - loss: 0.0051 - val_loss: 0.0234
# Learning Rate:  tf.Tensor(9.494834e-05, shape=(), dtype=float32)
# Epoch 23/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0049 - val_loss: 0.0237
# val4.csv val_performance = 0.02366233989596367
# val4.csv val accuracy = 0.97153
# Learning Rate:  0.002798
# Epoch 1/23
# 3443/3443 [==============================] - 123s 35ms/step - loss: 0.1346 - val_loss: 0.0887
# Learning Rate:  tf.Tensor(0.002675134, shape=(), dtype=float32)
# Epoch 2/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0796 - val_loss: 0.0708
# Learning Rate:  tf.Tensor(0.0025522679, shape=(), dtype=float32)
# Epoch 3/23
# 3443/3443 [==============================] - 121s 35ms/step - loss: 0.0646 - val_loss: 0.0631
# Learning Rate:  tf.Tensor(0.002429402, shape=(), dtype=float32)
# Epoch 4/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0603 - val_loss: 0.0599
# Learning Rate:  tf.Tensor(0.0023065358, shape=(), dtype=float32)
# Epoch 5/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0551 - val_loss: 0.0836
# Learning Rate:  tf.Tensor(0.00218367, shape=(), dtype=float32)
# Epoch 6/23
# 3443/3443 [==============================] - 126s 37ms/step - loss: 0.0525 - val_loss: 0.0559
# Learning Rate:  tf.Tensor(0.002060804, shape=(), dtype=float32)
# Epoch 7/23
# 3443/3443 [==============================] - 127s 37ms/step - loss: 0.0513 - val_loss: 0.0545
# Learning Rate:  tf.Tensor(0.001937938, shape=(), dtype=float32)
# Epoch 8/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0486 - val_loss: 0.0558
# Learning Rate:  tf.Tensor(0.001815072, shape=(), dtype=float32)
# Epoch 9/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0442 - val_loss: 0.0482
# Learning Rate:  tf.Tensor(0.001692206, shape=(), dtype=float32)
# Epoch 10/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0436 - val_loss: 0.0465
# Learning Rate:  tf.Tensor(0.0015693401, shape=(), dtype=float32)
# Epoch 11/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0353 - val_loss: 0.0443
# Learning Rate:  tf.Tensor(0.0014464741, shape=(), dtype=float32)
# Epoch 12/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0373 - val_loss: 0.0422
# Learning Rate:  tf.Tensor(0.0013236081, shape=(), dtype=float32)
# Epoch 13/23
# 3443/3443 [==============================] - 122s 35ms/step - loss: 0.0314 - val_loss: 0.0438
# Learning Rate:  tf.Tensor(0.0012007422, shape=(), dtype=float32)
# Epoch 14/23
# 3443/3443 [==============================] - 123s 36ms/step - loss: 0.0287 - val_loss: 0.0436
# Learning Rate:  tf.Tensor(0.0010778762, shape=(), dtype=float32)
# Epoch 15/23
# 3443/3443 [==============================] - 122s 36ms/step - loss: 0.0300 - val_loss: 0.0405
# Learning Rate:  tf.Tensor(0.0009550102, shape=(), dtype=float32)
# Epoch 16/23
# 3443/3443 [==============================] - 122s 36ms/step - loss: 0.0249 - val_loss: 0.0402
# Learning Rate:  tf.Tensor(0.0008321442, shape=(), dtype=float32)
# Epoch 17/23
# 3443/3443 [==============================] - 123s 36ms/step - loss: 0.0214 - val_loss: 0.0353
# Learning Rate:  tf.Tensor(0.0007092783, shape=(), dtype=float32)
# Epoch 18/23
# 3443/3443 [==============================] - 123s 36ms/step - loss: 0.0199 - val_loss: 0.0374
# Learning Rate:  tf.Tensor(0.00058641215, shape=(), dtype=float32)
# Epoch 19/23
# 3443/3443 [==============================] - 123s 36ms/step - loss: 0.0169 - val_loss: 0.0333
# Learning Rate:  tf.Tensor(0.0004635465, shape=(), dtype=float32)
# Epoch 20/23
# 3443/3443 [==============================] - 123s 36ms/step - loss: 0.0151 - val_loss: 0.0327
# Learning Rate:  tf.Tensor(0.00034068036, shape=(), dtype=float32)
# Epoch 21/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0126 - val_loss: 0.0330
# Learning Rate:  tf.Tensor(0.00021781446, shape=(), dtype=float32)
# Epoch 22/23
# 3443/3443 [==============================] - 124s 36ms/step - loss: 0.0115 - val_loss: 0.0333
# Learning Rate:  tf.Tensor(9.494834e-05, shape=(), dtype=float32)
# Epoch 23/23
# 3443/3443 [==============================] - 123s 36ms/step - loss: 0.0112 - val_loss: 0.0331
# val5.csv val_performance = 0.03310081362724304
# val5.csv val accuracy = 0.96601
# Learning Rate:  0.002798
# Epoch 1/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.1503 - val_loss: 0.0983
# Learning Rate:  tf.Tensor(0.002675134, shape=(), dtype=float32)
# Epoch 2/23
# 3443/3443 [==============================] - 124s 36ms/step - loss: 0.0817 - val_loss: 0.0694
# Learning Rate:  tf.Tensor(0.0025522679, shape=(), dtype=float32)
# Epoch 3/23
# 3443/3443 [==============================] - 123s 36ms/step - loss: 0.0614 - val_loss: 0.0619
# Learning Rate:  tf.Tensor(0.002429402, shape=(), dtype=float32)
# Epoch 4/23
# 3443/3443 [==============================] - 124s 36ms/step - loss: 0.0565 - val_loss: 0.0547
# Learning Rate:  tf.Tensor(0.0023065358, shape=(), dtype=float32)
# Epoch 5/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0538 - val_loss: 0.0490
# Learning Rate:  tf.Tensor(0.00218367, shape=(), dtype=float32)
# Epoch 6/23
# 3443/3443 [==============================] - 127s 37ms/step - loss: 0.0464 - val_loss: 0.0492
# Learning Rate:  tf.Tensor(0.002060804, shape=(), dtype=float32)
# Epoch 7/23
# 3443/3443 [==============================] - 134s 39ms/step - loss: 0.0452 - val_loss: 0.0450
# Learning Rate:  tf.Tensor(0.001937938, shape=(), dtype=float32)
# Epoch 8/23
# 3443/3443 [==============================] - 124s 36ms/step - loss: 0.0418 - val_loss: 0.0487
# Learning Rate:  tf.Tensor(0.001815072, shape=(), dtype=float32)
# Epoch 9/23
# 3443/3443 [==============================] - 124s 36ms/step - loss: 0.0360 - val_loss: 0.0550
# Learning Rate:  tf.Tensor(0.001692206, shape=(), dtype=float32)
# Epoch 10/23
# 3443/3443 [==============================] - 124s 36ms/step - loss: 0.0350 - val_loss: 0.0415
# Learning Rate:  tf.Tensor(0.0015693401, shape=(), dtype=float32)
# Epoch 11/23
# 3443/3443 [==============================] - 124s 36ms/step - loss: 0.0302 - val_loss: 0.0410
# Learning Rate:  tf.Tensor(0.0014464741, shape=(), dtype=float32)
# Epoch 12/23
# 3443/3443 [==============================] - 126s 37ms/step - loss: 0.0280 - val_loss: 0.0362
# Learning Rate:  tf.Tensor(0.0013236081, shape=(), dtype=float32)
# Epoch 13/23
# 3443/3443 [==============================] - 131s 38ms/step - loss: 0.0262 - val_loss: 0.0376
# Learning Rate:  tf.Tensor(0.0012007422, shape=(), dtype=float32)
# Epoch 14/23
# 3443/3443 [==============================] - 124s 36ms/step - loss: 0.0227 - val_loss: 0.0455
# Learning Rate:  tf.Tensor(0.0010778762, shape=(), dtype=float32)
# Epoch 15/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0219 - val_loss: 0.0383
# Learning Rate:  tf.Tensor(0.0009550102, shape=(), dtype=float32)
# Epoch 16/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0181 - val_loss: 0.0333
# Learning Rate:  tf.Tensor(0.0008321442, shape=(), dtype=float32)
# Epoch 17/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0152 - val_loss: 0.0290
# Learning Rate:  tf.Tensor(0.0007092783, shape=(), dtype=float32)
# Epoch 18/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0125 - val_loss: 0.0334
# Learning Rate:  tf.Tensor(0.00058641215, shape=(), dtype=float32)
# Epoch 19/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0114 - val_loss: 0.0310
# Learning Rate:  tf.Tensor(0.0004635465, shape=(), dtype=float32)
# Epoch 20/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0096 - val_loss: 0.0317
# Learning Rate:  tf.Tensor(0.00034068036, shape=(), dtype=float32)
# Epoch 21/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0083 - val_loss: 0.0296
# Learning Rate:  tf.Tensor(0.00021781446, shape=(), dtype=float32)
# Epoch 22/23
# 3443/3443 [==============================] - 125s 36ms/step - loss: 0.0076 - val_loss: 0.0283
# Learning Rate:  tf.Tensor(9.494834e-05, shape=(), dtype=float32)
# Epoch 23/23
# 3443/3443 [==============================] - 126s 36ms/step - loss: 0.0074 - val_loss: 0.0283
# val6.csv val_performance = 0.02834421396255493
# val6.csv val accuracy = 0.97059
# Learning Rate:  0.002798
# Epoch 1/23
# 3443/3443 [==============================] - 131s 38ms/step - loss: 0.1506 - val_loss: 0.0867
# Learning Rate:  tf.Tensor(0.002675134, shape=(), dtype=float32)
# Epoch 2/23
# 3443/3443 [==============================] - 131s 38ms/step - loss: 0.0703 - val_loss: 0.0542
# Learning Rate:  tf.Tensor(0.0025522679, shape=(), dtype=float32)
# Epoch 3/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0525 - val_loss: 0.0649
# Learning Rate:  tf.Tensor(0.002429402, shape=(), dtype=float32)
# Epoch 4/23
# 3443/3443 [==============================] - 131s 38ms/step - loss: 0.0469 - val_loss: 0.0392
# Learning Rate:  tf.Tensor(0.0023065358, shape=(), dtype=float32)
# Epoch 5/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0423 - val_loss: 0.0534
# Learning Rate:  tf.Tensor(0.00218367, shape=(), dtype=float32)
# Epoch 6/23
# 3443/3443 [==============================] - 131s 38ms/step - loss: 0.0382 - val_loss: 0.0430
# Learning Rate:  tf.Tensor(0.002060804, shape=(), dtype=float32)
# Epoch 7/23
# 3443/3443 [==============================] - 131s 38ms/step - loss: 0.0348 - val_loss: 0.0395
# Learning Rate:  tf.Tensor(0.001937938, shape=(), dtype=float32)
# Epoch 8/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0325 - val_loss: 0.0436
# Learning Rate:  tf.Tensor(0.001815072, shape=(), dtype=float32)
# Epoch 9/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0285 - val_loss: 0.0396
# Learning Rate:  tf.Tensor(0.001692206, shape=(), dtype=float32)
# Epoch 10/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0261 - val_loss: 0.0310
# Learning Rate:  tf.Tensor(0.0015693401, shape=(), dtype=float32)
# Epoch 11/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0245 - val_loss: 0.0429
# Learning Rate:  tf.Tensor(0.0014464741, shape=(), dtype=float32)
# Epoch 12/23
# 3443/3443 [==============================] - 134s 39ms/step - loss: 0.0210 - val_loss: 0.0332
# Learning Rate:  tf.Tensor(0.0013236081, shape=(), dtype=float32)
# Epoch 13/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0205 - val_loss: 0.0317
# Learning Rate:  tf.Tensor(0.0012007422, shape=(), dtype=float32)
# Epoch 14/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0178 - val_loss: 0.0296
# Learning Rate:  tf.Tensor(0.0010778762, shape=(), dtype=float32)
# Epoch 15/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0153 - val_loss: 0.0285
# Learning Rate:  tf.Tensor(0.0009550102, shape=(), dtype=float32)
# Epoch 16/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0134 - val_loss: 0.0299
# Learning Rate:  tf.Tensor(0.0008321442, shape=(), dtype=float32)
# Epoch 17/23
# 3443/3443 [==============================] - 134s 39ms/step - loss: 0.0124 - val_loss: 0.0273
# Learning Rate:  tf.Tensor(0.0007092783, shape=(), dtype=float32)
# Epoch 18/23
# 3443/3443 [==============================] - 137s 40ms/step - loss: 0.0095 - val_loss: 0.0275
# Learning Rate:  tf.Tensor(0.00058641215, shape=(), dtype=float32)
# Epoch 19/23
# 3443/3443 [==============================] - 133s 39ms/step - loss: 0.0088 - val_loss: 0.0281
# Learning Rate:  tf.Tensor(0.0004635465, shape=(), dtype=float32)
# Epoch 20/23
# 3443/3443 [==============================] - 140s 41ms/step - loss: 0.0080 - val_loss: 0.0264
# Learning Rate:  tf.Tensor(0.00034068036, shape=(), dtype=float32)
# Epoch 21/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0065 - val_loss: 0.0246
# Learning Rate:  tf.Tensor(0.00021781446, shape=(), dtype=float32)
# Epoch 22/23
# 3443/3443 [==============================] - 132s 38ms/step - loss: 0.0057 - val_loss: 0.0244
# Learning Rate:  tf.Tensor(9.494834e-05, shape=(), dtype=float32)
# Epoch 23/23
# 3443/3443 [==============================] - 133s 39ms/step - loss: 0.0054 - val_loss: 0.0242
# val7.csv val_performance = 0.02424565702676773
# val7.csv val accuracy = 0.9724
