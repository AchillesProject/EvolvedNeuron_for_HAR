# %% [markdown]
# <div class="alert" style="background-color:#BBA14F; color:white; padding:0px 10px; border-radius:5px;">
#     <h1 style='margin:15px 15px; color:#000000; font-size:32px'><b>New Recurrent Network (best21_v27)</b></h1>
#         <h2 style='margin:15px 15px; color:#000000; font-size:24px'>Human Activity Recognition Problem</h2>
# </div>
#
# The work is under the **"Master Thesis"** by **Chau Tran** with the supervision from **Prof. Roland Olsson**.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.python.util.tf_export import keras_export
from tensorflow.keras.backend import eval

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, RobustScaler, StandardScaler

import tensorboard
import keras
from keras.utils import tf_utils
import pandas as pd #pd.plotting.register_matplotlib_converters
import numpy as np
import sys, os, math, time, datetime, re

import matplotlib.pyplot as plt

print("tf: ", tf.__version__)
print("tb: ", tensorboard.__version__)
print(os.getcwd())

DTYPE = tf.float64
RANDOM_SEED = 42
ISMOORE_DATASETS = True
timestep = 40
tf.random.set_seed(np.random.seed(RANDOM_SEED))
tf.get_logger().setLevel('ERROR')
tf.autograph.set_verbosity(1)
tf.config.set_visible_devices([], 'GPU')
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '1'

tf.keras.backend.set_floatx('float64')

snapshot = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
path = '../../../../Datasets/6_har/0_WISDM/WISDM_ar_v1.1/WISDM_ar_v1.1_processed/WISDM_ar_v1.1_wt_overlap'
# Debugging with Tensorboard
logdir="logs/fit/rnn_v1_1/" + snapshot
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
# tf.debugging.experimental.enable_dump_debug_info(logdir, tensor_debug_mode="FULL_HEALTH", circular_buffer_size=-1)

with open("../../params/params_har.txt") as f:
    hyperparams = dict([re.sub('['+' ,\n'+']','',x.replace(' .', '')).split('=') for x in f][1:-1])
hyperparams = dict([k, float(v)] for k, v in hyperparams.items())
hyperparams['testSize'] = 0.500
hyperparams['noUnits'] = 81
hyperparams['timestep'] = 40
print(hyperparams)

def transform_label(labels):
    labels_tf = np.array([], dtype=int)
    for labels_i in labels:
        labels_tf = np.append(labels_tf, np.where(labels_i == 1)[0].astype(int), axis=0)
    return labels_tf.reshape(-1, 1)

def plot_cm(cM, labels,title):
    # normalizing the confusionMatrix for showing the probabilities
    cmNormalized = np.around((cM/cM.sum(axis=1)[:,None])*100,2)
    # creating a figure object
    fig = plt.figure()
    # plotting the confusion matrix
    plt.imshow(cmNormalized,interpolation=None,cmap = plt.cm.Blues)
    # creating a color bar and setting the limits
    plt.colorbar()
    plt.clim(0,100)
    # assiging the title, x and y labels
    plt.xlabel('Predicted Values')
    plt.ylabel('Ground Truth')
    plt.title(title + '\n%age confidence')
    # defining the ticks for the x and y axis
    plt.xticks(range(len(labels)),labels,rotation = 60)
    plt.yticks(range(len(labels)),labels)
    # number of occurences in the boxes
    width, height = cM.shape 
    print('Accuracy for each class is given below.')
    for predicted in range(width):
        for real in range(height):
            color = 'black'
            if(predicted == real):
                color = 'white'
                print(labels[predicted].ljust(12)+ ':', cmNormalized[predicted,real], '%')
            plt.gca().annotate(
                    '{:d}'.format(int(cmNormalized[predicted,real])),xy=(real, predicted),
                    horizontalalignment = 'center',verticalalignment = 'center',color = color)
    # making sure that the figure is not clipped
    plt.tight_layout()
    plt.show()

def plot_cms(cMs, labels, row_no, col_no, title):
    # normalizing the confusionMatrix for showing the probabilities
    cmNormalized = np.around((cM/cM.sum(axis=1)[:,None])*100,2)
    # creating a figure object
    fig = plt.figure()
    # plotting the confusion matrix
    plt.imshow(cmNormalized,interpolation=None,cmap = plt.cm.Blues)
    # creating a color bar and setting the limits
    plt.colorbar()
    plt.clim(0,100)
    # assiging the title, x and y labels
    plt.xlabel('Predicted Values')
    plt.ylabel('Ground Truth')
    plt.title(title + '\n%age confidence')
    # defining the ticks for the x and y axis
    plt.xticks(range(len(labels)),labels,rotation = 60)
    plt.yticks(range(len(labels)),labels)
    # number of occurences in the boxes
    width, height = cM.shape 
    print('Accuracy for each class is given below.')
    for predicted in range(width):
        for real in range(height):
            color = 'black'
            if(predicted == real):
                color = 'white'
                print(labels[predicted].ljust(12)+ ':', cmNormalized[predicted,real], '%')
            plt.gca().annotate(
                    '{:d}'.format(int(cmNormalized[predicted,real])),xy=(real, predicted),
                    horizontalalignment = 'center',verticalalignment = 'center',color = color)
    # making sure that the figure is not clipped
    plt.tight_layout()
    
def seperateValues(data, noInput, noOutput, isMoore=True):
    x_data, y_data = None, None
    for i in range(data.shape[0]):
        if isMoore:
            x_data_i = data[i].reshape(-1, noInput+noOutput)
            x_data_i, y_data_i = x_data_i[:, 0:noInput], x_data_i[-1, noInput:]
        else:
            x_data_i = data[i][:-1].reshape(-1, noInput)
            y_data_i = data[i][-1].reshape(-1, noOutput)
        x_data = x_data_i[np.newaxis,:,:] if x_data is None else np.append(x_data, x_data_i[np.newaxis,:,:], axis=0)
        y_data = y_data_i.reshape(1, -1) if y_data is None else np.append(y_data, y_data_i.reshape(1, -1), axis=0)
    return x_data, y_data

def fromBit_v0( b ) :
    return -0.9 if b == 0.0 else 0.9

def fromBit_v1( b ) :
    return 0 if b == 0.0 else 1

def isCorrect( target, actual ) :
    y1 = False if target < 0.0 else True
    y2 = False if actual < 0.0 else True
    return y1 == y2 

class CustomMetricError(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name='custom_metric_error', dtype=None, threshold=0.5):
        super(CustomMetricError, self).__init__(
            customMetricfn_tensor, name, dtype=dtype, threshold=threshold)

    def customMetricfn_tensor(true, pred, threshold=0.5):
        true = tf.convert_to_tensor(true)
        pred = tf.convert_to_tensor(pred)
        threshold = tf.cast(threshold, pred.dtype)
        pred = tf.cast(pred >= threshold, pred.dtype)
        true = tf.cast(true >= threshold, true.dtype)
        return keras.backend.mean(tf.equal(true, pred), axis=-1)

def customMetricfn(y_true, y_pred):
    numCorrect = 0
    for i in range( y_true.shape[0] ) :
        for j in range( y_pred.shape[ 1 ] ) :
            if isCorrect( y_true[ i, j ], y_pred[ i, j ] ) :
                numCorrect += 1
    return (numCorrect/(y_pred.shape[1]*y_true.shape[0]))

def indexOfMax( xs ) :
    m, k = xs[ 0 ], 0
    for i in range( 0, xs.size ) :
        if xs[ i ] > m :
            m = xs[ i ]
            k = i
    return k

def customMetricfn_full(y_true, y_pred):
    numCorrect = 0
    for i in range(y_pred.shape[0]) :
        if indexOfMax(y_pred[i]) == indexOfMax(y_val[i]) :
            numCorrect += 1
    return numCorrect/y_pred.shape[0]
            
def srelu(x):
    return tf.keras.backend.clip(x, -1, 1)

def _generate_zero_filled_state_for_cell(cell, inputs, batch_size, dtype):
    if inputs is not None:
        batch_size = tf.shape(inputs)[0]
        dtype = inputs.dtype
    return _generate_zero_filled_state(batch_size, cell.state_size, dtype)

def _generate_zero_filled_state(batch_size_tensor, state_size, dtype):
    def create_zeros(unnested_state_size):
        flat_dims = tf.TensorShape(unnested_state_size).as_list()
        init_state_size = [batch_size_tensor] + flat_dims
        return tf.zeros(init_state_size, dtype=dtype)
    
    if batch_size_tensor is None or dtype is None:
        raise ValueError(
            'batch_size and dtype cannot be None while constructing initial state. '
            f'Received: batch_size={batch_size_tensor}, dtype={dtype}')

    return tf.nest.map_structure(create_zeros, state_size)  if tf.nest.is_nested(state_size) else create_zeros(state_size)

class RNN_plus_v1_27_cell(tf.keras.layers.LSTMCell):
    def __init__(self, units, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', bias_initializer='zeros', dropout=0., recurrent_dropout=0., use_bias=True, **kwargs):
        if units < 0:
            raise ValueError(f'Received an invalid value for argument `units`, '
                                f'expected a positive integer, got {units}.')
        # By default use cached variable under v2 mode, see b/143699808.
        if tf.compat.v1.executing_eagerly_outside_functions():
            self._enable_caching_device = kwargs.pop('enable_caching_device', True)
        else:
            self._enable_caching_device = kwargs.pop('enable_caching_device', False)
        super(RNN_plus_v1_27_cell, self).__init__(units, **kwargs)
        self.units = units
        self.state_size = self.units
        self.output_size = self.units
        
        self.kernel_initializer = tf.keras.initializers.get(kernel_initializer)
        self.recurrent_initializer = tf.keras.initializers.get(recurrent_initializer)
        self.aux_initializer = tf.keras.initializers.get('zeros')
        self.bias_initializer = tf.keras.initializers.get(bias_initializer)
        
        self.dropout = min(1., max(0., dropout))
        self.recurrent_dropout = min(1., max(0., recurrent_dropout))
        self.state_size = [self.units, self.units, self.units, self.units, self.units]
        self.output_size = self.units
        self.use_bias = True
        self.cell_dtype = DTYPE
    
    def build(self, input_shape):
        input_dim = input_shape[-1]
        self.kernel = self.add_weight(shape=(input_dim, self.units * 2), name='w_input', initializer=self.kernel_initializer, regularizer=None, constraint=None, dtype=self.cell_dtype)
        self.recurrent_kernel = self.add_weight(shape=(self.units, self.units * 4), name='w_otherpeeps', initializer=self.recurrent_initializer, regularizer=None, constraint=None, dtype=self.cell_dtype)
        self.aux_kernel  = self.add_weight(shape=(5, self.units), name='w_aux', initializer=self.recurrent_initializer, regularizer=None, constraint=None, dtype=self.cell_dtype)
        self.bias = self.add_weight( shape=(self.units,), name='b', initializer=self.bias_initializer, regularizer=None, constraint=None, dtype=self.cell_dtype) if self.use_bias else None
        self.built = True
        
    def call(self, inputs, states, training=None):
        state0, state1, state2, state3, prev_output = states[0], states[1], states[2], states[3], states[4]
        
        w_in_0, w_in_2 = tf.split(self.kernel, num_or_size_splits=2, axis=1)

        w_op0, w_op2, w_op3, w_op4 = tf.split(self.recurrent_kernel, num_or_size_splits=4, axis=1)
        w_op0 = tf.linalg.set_diag(w_op0, np.zeros((self.units,), dtype=np.float64))
        w_op2 = tf.linalg.set_diag(w_op2, np.zeros((self.units,), dtype=np.float64))
        w_op3 = tf.linalg.set_diag(w_op3, np.zeros((self.units,), dtype=np.float64))
        w_op4 = tf.linalg.set_diag(w_op4, np.zeros((self.units,), dtype=np.float64))
    
        w_aux = self.aux_kernel
        
        inputs_0 = tf.keras.backend.dot(inputs, w_in_0)
        # inputs_1 = tf.keras.backend.dot(inputs, w_in_1)
        inputs_2 = tf.keras.backend.dot(inputs, w_in_2)
        
        if self.bias is not None:
            inputs_0 = tf.keras.backend.bias_add(inputs_0, self.bias)
            # inputs_1 = tf.keras.backend.bias_add(inputs_1, self.bias)
            inputs_2 = tf.keras.backend.bias_add(inputs_2, self.bias)
            
        op0 = tf.keras.backend.dot(state0, w_op0)
        # op1 = tf.keras.backend.dot(state0, w_op1)
        op2 = tf.keras.backend.dot(state0, w_op2)
        op3 = tf.keras.backend.dot(state0, w_op3)
        op4 = tf.keras.backend.dot(state0, w_op4)
        
        z1 = tf.nn.tanh(tf.nn.relu(op0 + w_aux[0]*state0 + inputs_0))
        z2 = tf.nn.tanh(tf.nn.relu(op2 + w_aux[1]*state0))
        z3 = tf.nn.tanh(tf.nn.relu(inputs_2))
        z  = z1 - (z2 + z3)
        output = prev_output - (z - state0)*z
        f = w_aux[4]*z + op0

        return output, [z, state0, f, state2, output]
    
    def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
        return list(_generate_zero_filled_state_for_cell(self, inputs, batch_size, dtype))

class LearningRateLoggingCallback(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        print("Learning Rate: ", self.model.optimizer.learning_rate.lr)
    
    def on_epoch_end(self, epoch, logs=None):
        tf.summary.scalar('learning rate', self.model.optimizer.learning_rate.lr, step=epoch)

class customLRSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, batchSize, initialLearningRate, learningRateDecay, 
                 decayDurationFactor, numTrainingSteps, name=None):
        self.name                 = name
        self.cell_dtype           = DTYPE
        self.batchSize            = tf.constant(batchSize, dtype=self.cell_dtype, name="bz")
        self.initialLearningRate  = tf.constant(initialLearningRate, dtype=self.cell_dtype, name="lr0") 
        self.learningRateDecay    = tf.constant(learningRateDecay, dtype=self.cell_dtype, name="alpha")
        self.decayDurationFactor  = tf.constant(decayDurationFactor, dtype=self.cell_dtype, name="beta")
        self.numTrainingSteps     = tf.constant(numTrainingSteps, dtype=self.cell_dtype, name="ortho")
        self.T                    = tf.constant(self.decayDurationFactor*(self.numTrainingSteps/self.batchSize), 
                                                dtype=self.cell_dtype, name="T")
        self.lr                   = tf.Variable(self.initialLearningRate, dtype=self.cell_dtype, name="lr")
    
    def __call__(self, step):
        self.t = tf.cast(step, self.cell_dtype)
        self.lr = tf.cond(self.t > self.T, 
           lambda: self.learningRateDecay * self.initialLearningRate,
           lambda: self.initialLearningRate -(1.0-self.learningRateDecay)*self.initialLearningRate*self.t/self.T
          )
        return self.lr
    
    def get_config(self):
        return {
            "name":           self.name,
            "cell_dtype":     self.cell_dtype,
            "batchSize":      self.batchSize,
            "initial_lr":     self.initialLearningRate,
            "decay_rate":     self.learningRateDecay,
            "decay_duration": self.decayDurationFactor,
            "training_step":  self.numTrainingSteps,
            "curr_lr":        self.lr
        }
    
def rnn_plus_model(noInput, noOutput, timestep):
    """Builds a recurrent model."""
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.RNN(cell=RNN_plus_v1_27_cell(units=hyperparams['noUnits']), input_shape=[timestep, noInput], unroll=False, name='RNNp_layer', dtype=DTYPE))
    model.add(tf.keras.layers.Dense(noInput+noOutput, activation='tanh', name='MLP_layer'))
    model.add(tf.keras.layers.Dense(noOutput, name='Output_layer'))
    optimizer = tf.keras.optimizers.Adam(learning_rate=customLRSchedule(hyperparams['batchSize'], hyperparams['initialLearningRate'], hyperparams['learningRateDecay'], hyperparams['decayDurationFactor'], hyperparams['numTrainingSteps']), \
                                        beta_1=hyperparams['beta1'], beta_2=hyperparams['beta2'], epsilon=hyperparams['epsilon'], amsgrad=False, name="tunedAdam")
    model.compile(optimizer=optimizer, loss = 'mse', run_eagerly=False)
    print(tf.keras.backend.floatx())
    print(model.summary())
    return model
# Out:
# tf:  2.6.0
# tb:  2.6.0
# /home/ifeai/ChauTran/git/0_HIOF_Studying/0_MasterProject/tf_implementation/notebooks/rnnplus_for_har
# {'batchSize': 4.0, 'numTrainingSteps': 320000.0, 'beta1': 0.974833, 'beta2': 0.99689, 'epsilon': 0.00388, 'decayDurationFactor': 0.979079, 'initialLearningRate': 0.002798, 'learningRateDecay': 0.001025, 'glorotScaleFactor': 0.1, 'orthogonalScaleFactor': 0.1, 'testSize': 0.5, 'noUnits': 81, 'timestep': 40}

# %%
if __name__ == '__main__':
    ISMOORE_DATASETS = True
    noIn, noOut = 3, 6
    path = './../../../Datasets/6_har/0_WISDM/WISDM_ar_v1.1/wisdm_script_and_data/wisdm_script_and_data/WISDM/testdata'
    fileslist = [f for f in sorted(os.listdir(path)) if os.path.isfile(os.path.join(path, f))]
    logdir = f"./logs/scalars/wisdm"
    tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
    print(tf.keras.backend.floatx())
    result_history = {}
    for file_no in range(8):
        trainFile = f'train{file_no}.csv'
        valFile   = f'val{file_no}.csv'
        df_train  = np.array(pd.read_csv(os.path.join(path, trainFile), skiprows=1))
        df_val    = np.array(pd.read_csv(os.path.join(path, valFile), skiprows=1))

        scaler    = StandardScaler()
        x_train, y_train = seperateValues(df_train, noIn, noOut, isMoore=ISMOORE_DATASETS)
        x_val,   y_val   = seperateValues(df_val,   noIn, noOut, isMoore=ISMOORE_DATASETS) 
        x_train   = (scaler.fit_transform(x_train.reshape(x_train.shape[0], -1))).reshape(x_train.shape[0], hyperparams['timestep'], noIn)
        x_val     = (scaler.fit_transform(x_val.reshape(x_val.shape[0], -1))).reshape(x_val.shape[0], hyperparams['timestep'], noIn)

        model = rnn_plus_model(noIn, noOut, timestep=hyperparams['timestep'])
        model_history = model.fit(
                            x_train, y_train,
                            batch_size=int(hyperparams['batchSize']),
                            verbose=1, # Suppress chatty output; use Tensorboard instead
                            epochs=int(hyperparams['numTrainingSteps']/(x_train.shape[0])),
                            validation_data=(x_val, y_val),
                            shuffle=True,
                            use_multiprocessing=False,
                            callbacks=[tensorboard_callback, LearningRateLoggingCallback()],
                        )
        y_pred = model.predict(x_val, verbose=0, batch_size=int(hyperparams['batchSize']))
        val_performance = model.evaluate(x_val, y_val, batch_size=int(hyperparams['batchSize']), verbose=0)
        result_history[f"{valFile}"] = {}
        result_history[f"{valFile}"]['y_val'] = y_val
        result_history[f"{valFile}"]['y_pred'] = y_pred
        result_history[f"{valFile}"]['val_performance'] = val_performance
        result_history[f"{valFile}"]['val_accuracy'] = round(customMetricfn_full(y_val, y_pred), 5)
        print(f"{valFile} val_performance = {val_performance}")
        print(f"{valFile} val accuracy = {round(customMetricfn_full(y_val, y_pred), 5)}")
        predictedClass = np.zeros((y_pred.shape[0]), dtype = int)
        groundTruthClass = np.zeros((y_val.shape[0]), dtype = int)
        for instance in range (y_val.shape[0]):
            predictedClass[instance] = np.argmax(y_pred[instance,:])
            groundTruthClass[instance] = np.argmax(y_val[instance,:])
        predictedClass = np.where(predictedClass.astype(str) == '0', 'Walking', predictedClass)
        predictedClass = np.where(predictedClass.astype(str) == '1', 'Jogging', predictedClass)
        predictedClass = np.where(predictedClass.astype(str) == '2', 'Sitting', predictedClass)
        predictedClass = np.where(predictedClass.astype(str) == '3', 'Standing', predictedClass)
        predictedClass = np.where(predictedClass.astype(str) == '4', 'Upstair', predictedClass)
        predictedClass = np.where(predictedClass.astype(str) == '5', 'Downstair', predictedClass)
        groundTruthClass = np.where(groundTruthClass.astype(str) == '0', 'Walking', groundTruthClass)
        groundTruthClass = np.where(groundTruthClass.astype(str) == '1', 'Jogging', groundTruthClass)
        groundTruthClass = np.where(groundTruthClass.astype(str) == '2', 'Sitting', groundTruthClass)
        groundTruthClass = np.where(groundTruthClass.astype(str) == '3', 'Standing', groundTruthClass)
        groundTruthClass = np.where(groundTruthClass.astype(str) == '4', 'Upstair', groundTruthClass)
        groundTruthClass = np.where(groundTruthClass.astype(str) == '5', 'Downstair', groundTruthClass)
        display(predictedClass)
        display(groundTruthClass)
        result_history[f"{valFile}"]['confusion_matrix'] = metrics.confusion_matrix(groundTruthClass, predictedClass)
        tags = np.array(['Walking', 'Jogging', 'Sitting', 'Standing', 'Upstair', 'Downstair'])
        # obtaining a confusion matrix  
        cm = metrics.confusion_matrix(groundTruthClass, predictedClass)
        # plotting the confusion matrix
        plot_cm(cm, tags, f'Confusion Matrix of {valFile}')
# Out:
# float64
# float64
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# RNNp_layer (RNN)             (None, 81)                27216
# _________________________________________________________________
# MLP_layer (Dense)            (None, 9)                 738
# _________________________________________________________________
# Output_layer (Dense)         (None, 6)                 60
# =================================================================
# Total params: 28,014
# Trainable params: 28,014
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/23
# Learning Rate:  <tf.Variable 'lr:0' shape=() dtype=float64, numpy=0.002798>
# 3443/3443 [==============================] - 50s 14ms/step - loss: 0.0390 - val_loss: 0.0257
# Epoch 2/23
# Learning Rate:  tf.Tensor(0.0026751340253423116, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0221 - val_loss: 0.0220
# Epoch 3/23
# Learning Rate:  tf.Tensor(0.002552268050684623, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0177 - val_loss: 0.0197
# Epoch 4/23
# Learning Rate:  tf.Tensor(0.0024294020760269345, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0159 - val_loss: 0.0163
# Epoch 5/23
# Learning Rate:  tf.Tensor(0.002306536101369246, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0151 - val_loss: 0.0147
# Epoch 6/23
# Learning Rate:  tf.Tensor(0.002183670126711558, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0140 - val_loss: 0.0153
# Epoch 7/23
# Learning Rate:  tf.Tensor(0.0020608041520538693, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0124 - val_loss: 0.0140
# Epoch 8/23
# Learning Rate:  tf.Tensor(0.0019379381773961808, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0124 - val_loss: 0.0144
# Epoch 9/23
# Learning Rate:  tf.Tensor(0.0018150722027384923, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0134 - val_loss: 0.0172
# Epoch 10/23
# Learning Rate:  tf.Tensor(0.001692206228080804, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0126 - val_loss: 0.0166
# Epoch 11/23
# Learning Rate:  tf.Tensor(0.0015693402534231154, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0108 - val_loss: 0.0143
# Epoch 12/23
# Learning Rate:  tf.Tensor(0.0014464742787654269, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0093 - val_loss: 0.0124
# Epoch 13/23
# Learning Rate:  tf.Tensor(0.0013236083041077383, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0084 - val_loss: 0.0121
# Epoch 14/23
# Learning Rate:  tf.Tensor(0.0012007423294500498, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0074 - val_loss: 0.0121
# Epoch 15/23
# Learning Rate:  tf.Tensor(0.0010778763547923613, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0062 - val_loss: 0.0111
# Epoch 16/23
# Learning Rate:  tf.Tensor(0.0009550103801346727, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0055 - val_loss: 0.0107
# Epoch 17/23
# Learning Rate:  tf.Tensor(0.0008321444054769844, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0044 - val_loss: 0.0098
# Epoch 18/23
# Learning Rate:  tf.Tensor(0.0007092784308192959, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0035 - val_loss: 0.0098
# Epoch 19/23
# Learning Rate:  tf.Tensor(0.0005864124561616078, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0029 - val_loss: 0.0089
# Epoch 20/23
# Learning Rate:  tf.Tensor(0.0004635464815039192, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0023 - val_loss: 0.0092
# Epoch 21/23
# Learning Rate:  tf.Tensor(0.0003406805068462307, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0019 - val_loss: 0.0090
# Epoch 22/23
# Learning Rate:  tf.Tensor(0.00021781453218854213, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0017 - val_loss: 0.0090
# Epoch 23/23
# Learning Rate:  tf.Tensor(9.49485575308536e-05, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0016 - val_loss: 0.0090
# val0.csv val_performance = 0.008968408061169433
# val0.csv val accuracy = 0.9663
# array(['Upstair', 'Downstair', 'Sitting', ..., 'Sitting', 'Walking',
#        'Jogging'], dtype='<U21')
# array(['Upstair', 'Downstair', 'Sitting', ..., 'Sitting', 'Walking',
#        'Jogging'], dtype='<U21')
# Accuracy for each class is given below.
# Walking     : 98.5 %
# Jogging     : 98.4 %
# Sitting     : 98.58 %
# Standing    : 99.68 %
# Upstair     : 92.36 %
# Downstair   : 85.88 %
# float64
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# RNNp_layer (RNN)             (None, 81)                27216
# _________________________________________________________________
# MLP_layer (Dense)            (None, 9)                 738
# _________________________________________________________________
# Output_layer (Dense)         (None, 6)                 60
# =================================================================
# Total params: 28,014
# Trainable params: 28,014
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/23
# Learning Rate:  <tf.Variable 'lr:0' shape=() dtype=float64, numpy=0.002798>
# 3443/3443 [==============================] - 50s 14ms/step - loss: 0.0397 - val_loss: 0.0234
# Epoch 2/23
# Learning Rate:  tf.Tensor(0.0026751340253423116, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0217 - val_loss: 0.0191
# Epoch 3/23
# Learning Rate:  tf.Tensor(0.002552268050684623, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0199 - val_loss: 0.0173
# Epoch 4/23
# Learning Rate:  tf.Tensor(0.0024294020760269345, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0190 - val_loss: 0.0188
# Epoch 5/23
# Learning Rate:  tf.Tensor(0.002306536101369246, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0175 - val_loss: 0.0185
# Epoch 6/23
# Learning Rate:  tf.Tensor(0.002183670126711558, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0167 - val_loss: 0.0213
# Epoch 7/23
# Learning Rate:  tf.Tensor(0.0020608041520538693, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0165 - val_loss: 0.0185
# Epoch 8/23
# Learning Rate:  tf.Tensor(0.0019379381773961808, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0215 - val_loss: 0.0246
# Epoch 9/23
# Learning Rate:  tf.Tensor(0.0018150722027384923, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0161 - val_loss: 0.0192
# Epoch 10/23
# Learning Rate:  tf.Tensor(0.001692206228080804, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0138 - val_loss: 0.0160
# Epoch 11/23
# Learning Rate:  tf.Tensor(0.0015693402534231154, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0138 - val_loss: 0.0146
# Epoch 12/23
# Learning Rate:  tf.Tensor(0.0014464742787654269, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0137 - val_loss: 0.0172
# Epoch 13/23
# Learning Rate:  tf.Tensor(0.0013236083041077383, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0123 - val_loss: 0.0149
# Epoch 14/23
# Learning Rate:  tf.Tensor(0.0012007423294500498, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0104 - val_loss: 0.0137
# Epoch 15/23
# Learning Rate:  tf.Tensor(0.0010778763547923613, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0094 - val_loss: 0.0118
# Epoch 16/23
# Learning Rate:  tf.Tensor(0.0009550103801346727, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0082 - val_loss: 0.0123
# Epoch 17/23
# Learning Rate:  tf.Tensor(0.0008321444054769844, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0071 - val_loss: 0.0122
# Epoch 18/23
# Learning Rate:  tf.Tensor(0.0007092784308192959, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0060 - val_loss: 0.0116
# Epoch 19/23
# Learning Rate:  tf.Tensor(0.0005864124561616078, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0051 - val_loss: 0.0119
# Epoch 20/23
# Learning Rate:  tf.Tensor(0.0004635464815039192, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0044 - val_loss: 0.0112
# Epoch 21/23
# Learning Rate:  tf.Tensor(0.0003406805068462307, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0036 - val_loss: 0.0112
# Epoch 22/23
# Learning Rate:  tf.Tensor(0.00021781453218854213, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0031 - val_loss: 0.0111
# Epoch 23/23
# Learning Rate:  tf.Tensor(9.49485575308536e-05, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0029 - val_loss: 0.0111
# val1.csv val_performance = 0.011061291960322184
# val1.csv val accuracy = 0.96173
# array(['Jogging', 'Downstair', 'Jogging', ..., 'Jogging', 'Downstair',
#        'Downstair'], dtype='<U21')
# array(['Jogging', 'Downstair', 'Jogging', ..., 'Jogging', 'Downstair',
#        'Downstair'], dtype='<U21')
# Accuracy for each class is given below.
# Walking     : 98.5 %
# Jogging     : 98.09 %
# Sitting     : 98.92 %
# Standing    : 98.57 %
# Upstair     : 87.64 %
# Downstair   : 87.43 %
# float64
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# RNNp_layer (RNN)             (None, 81)                27216
# _________________________________________________________________
# MLP_layer (Dense)            (None, 9)                 738
# _________________________________________________________________
# Output_layer (Dense)         (None, 6)                 60
# =================================================================
# Total params: 28,014
# Trainable params: 28,014
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/23
# Learning Rate:  <tf.Variable 'lr:0' shape=() dtype=float64, numpy=0.002798>
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0429 - val_loss: 0.0272
# Epoch 2/23
# Learning Rate:  tf.Tensor(0.0026751340253423116, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0233 - val_loss: 0.0208
# Epoch 3/23
# Learning Rate:  tf.Tensor(0.002552268050684623, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0194 - val_loss: 0.0175
# Epoch 4/23
# Learning Rate:  tf.Tensor(0.0024294020760269345, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0167 - val_loss: 0.0190
# Epoch 5/23
# Learning Rate:  tf.Tensor(0.002306536101369246, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0150 - val_loss: 0.0148
# Epoch 6/23
# Learning Rate:  tf.Tensor(0.002183670126711558, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0137 - val_loss: 0.0136
# Epoch 7/23
# Learning Rate:  tf.Tensor(0.0020608041520538693, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0119 - val_loss: 0.0115
# Epoch 8/23
# Learning Rate:  tf.Tensor(0.0019379381773961808, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0106 - val_loss: 0.0125
# Epoch 9/23
# Learning Rate:  tf.Tensor(0.0018150722027384923, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0102 - val_loss: 0.0124
# Epoch 10/23
# Learning Rate:  tf.Tensor(0.001692206228080804, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0091 - val_loss: 0.0133
# Epoch 11/23
# Learning Rate:  tf.Tensor(0.0015693402534231154, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0083 - val_loss: 0.0106
# Epoch 12/23
# Learning Rate:  tf.Tensor(0.0014464742787654269, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0076 - val_loss: 0.0103
# Epoch 13/23
# Learning Rate:  tf.Tensor(0.0013236083041077383, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0063 - val_loss: 0.0105
# Epoch 14/23
# Learning Rate:  tf.Tensor(0.0012007423294500498, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0053 - val_loss: 0.0091
# Epoch 15/23
# Learning Rate:  tf.Tensor(0.0010778763547923613, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0047 - val_loss: 0.0099
# Epoch 16/23
# Learning Rate:  tf.Tensor(0.0009550103801346727, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0040 - val_loss: 0.0086
# Epoch 17/23
# Learning Rate:  tf.Tensor(0.0008321444054769844, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0031 - val_loss: 0.0093
# Epoch 18/23
# Learning Rate:  tf.Tensor(0.0007092784308192959, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0024 - val_loss: 0.0082
# Epoch 19/23
# Learning Rate:  tf.Tensor(0.0005864124561616078, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0019 - val_loss: 0.0079
# Epoch 20/23
# Learning Rate:  tf.Tensor(0.0004635464815039192, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0014 - val_loss: 0.0076
# Epoch 21/23
# Learning Rate:  tf.Tensor(0.0003406805068462307, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0012 - val_loss: 0.0075
# Epoch 22/23
# Learning Rate:  tf.Tensor(0.00021781453218854213, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0011 - val_loss: 0.0075
# Epoch 23/23
# Learning Rate:  tf.Tensor(9.49485575308536e-05, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0010 - val_loss: 0.0075
# val2.csv val_performance = 0.007541048900051747
# val2.csv val accuracy = 0.9708
# array(['Downstair', 'Jogging', 'Upstair', ..., 'Downstair', 'Upstair',
#        'Downstair'], dtype='<U21')
# array(['Downstair', 'Jogging', 'Upstair', ..., 'Downstair', 'Walking',
#        'Downstair'], dtype='<U21')
# Accuracy for each class is given below.
# Walking     : 98.64 %
# Jogging     : 98.88 %
# Sitting     : 98.66 %
# Standing    : 99.67 %
# Upstair     : 90.77 %
# Downstair   : 89.81 %
# float64
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# RNNp_layer (RNN)             (None, 81)                27216
# _________________________________________________________________
# MLP_layer (Dense)            (None, 9)                 738
# _________________________________________________________________
# Output_layer (Dense)         (None, 6)                 60
# =================================================================
# Total params: 28,014
# Trainable params: 28,014
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/23
# Learning Rate:  <tf.Variable 'lr:0' shape=() dtype=float64, numpy=0.002798>
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0416 - val_loss: 0.0298
# Epoch 2/23
# Learning Rate:  tf.Tensor(0.0026751340253423116, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0242 - val_loss: 0.0246
# Epoch 3/23
# Learning Rate:  tf.Tensor(0.002552268050684623, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0205 - val_loss: 0.0184
# Epoch 4/23
# Learning Rate:  tf.Tensor(0.0024294020760269345, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0192 - val_loss: 0.0213
# Epoch 5/23
# Learning Rate:  tf.Tensor(0.002306536101369246, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0169 - val_loss: 0.0180
# Epoch 6/23
# Learning Rate:  tf.Tensor(0.002183670126711558, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0155 - val_loss: 0.0194
# Epoch 7/23
# Learning Rate:  tf.Tensor(0.0020608041520538693, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0143 - val_loss: 0.0204
# Epoch 8/23
# Learning Rate:  tf.Tensor(0.0019379381773961808, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0137 - val_loss: 0.0166
# Epoch 9/23
# Learning Rate:  tf.Tensor(0.0018150722027384923, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0126 - val_loss: 0.0183
# Epoch 10/23
# Learning Rate:  tf.Tensor(0.001692206228080804, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0121 - val_loss: 0.0153
# Epoch 11/23
# Learning Rate:  tf.Tensor(0.0015693402534231154, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0117 - val_loss: 0.0181
# Epoch 12/23
# Learning Rate:  tf.Tensor(0.0014464742787654269, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0148 - val_loss: 0.0174
# Epoch 13/23
# Learning Rate:  tf.Tensor(0.0013236083041077383, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0104 - val_loss: 0.0145
# Epoch 14/23
# Learning Rate:  tf.Tensor(0.0012007423294500498, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0093 - val_loss: 0.0140
# Epoch 15/23
# Learning Rate:  tf.Tensor(0.0010778763547923613, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0079 - val_loss: 0.0137
# Epoch 16/23
# Learning Rate:  tf.Tensor(0.0009550103801346727, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0065 - val_loss: 0.0121
# Epoch 17/23
# Learning Rate:  tf.Tensor(0.0008321444054769844, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0058 - val_loss: 0.0118
# Epoch 18/23
# Learning Rate:  tf.Tensor(0.0007092784308192959, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0049 - val_loss: 0.0115
# Epoch 19/23
# Learning Rate:  tf.Tensor(0.0005864124561616078, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0037 - val_loss: 0.0114
# Epoch 20/23
# Learning Rate:  tf.Tensor(0.0004635464815039192, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0028 - val_loss: 0.0111
# Epoch 21/23
# Learning Rate:  tf.Tensor(0.0003406805068462307, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0023 - val_loss: 0.0111
# Epoch 22/23
# Learning Rate:  tf.Tensor(0.00021781453218854213, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0020 - val_loss: 0.0109
# Epoch 23/23
# Learning Rate:  tf.Tensor(9.49485575308536e-05, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0018 - val_loss: 0.0109
# val3.csv val_performance = 0.010933407896109462
# val3.csv val accuracy = 0.95947
# array(['Jogging', 'Standing', 'Downstair', ..., 'Downstair', 'Downstair',
#        'Upstair'], dtype='<U21')
# array(['Jogging', 'Standing', 'Downstair', ..., 'Downstair', 'Downstair',
#        'Upstair'], dtype='<U21')
# Accuracy for each class is given below.
# Walking     : 98.37 %
# Jogging     : 98.55 %
# Sitting     : 98.93 %
# Standing    : 99.35 %
# Upstair     : 85.86 %
# Downstair   : 86.07 %
# float64
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# RNNp_layer (RNN)             (None, 81)                27216
# _________________________________________________________________
# MLP_layer (Dense)            (None, 9)                 738
# _________________________________________________________________
# Output_layer (Dense)         (None, 6)                 60
# =================================================================
# Total params: 28,014
# Trainable params: 28,014
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/23
# Learning Rate:  <tf.Variable 'lr:0' shape=() dtype=float64, numpy=0.002798>
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0412 - val_loss: 0.0246
# Epoch 2/23
# Learning Rate:  tf.Tensor(0.0026751340253423116, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0220 - val_loss: 0.0221
# Epoch 3/23
# Learning Rate:  tf.Tensor(0.002552268050684623, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0223 - val_loss: 0.0219
# Epoch 4/23
# Learning Rate:  tf.Tensor(0.0024294020760269345, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0202 - val_loss: 0.0238
# Epoch 5/23
# Learning Rate:  tf.Tensor(0.002306536101369246, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0178 - val_loss: 0.0187
# Epoch 6/23
# Learning Rate:  tf.Tensor(0.002183670126711558, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0187 - val_loss: 0.0205
# Epoch 7/23
# Learning Rate:  tf.Tensor(0.0020608041520538693, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0174 - val_loss: 0.0208
# Epoch 8/23
# Learning Rate:  tf.Tensor(0.0019379381773961808, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0157 - val_loss: 0.0205
# Epoch 9/23
# Learning Rate:  tf.Tensor(0.0018150722027384923, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0150 - val_loss: 0.0159
# Epoch 10/23
# Learning Rate:  tf.Tensor(0.001692206228080804, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0142 - val_loss: 0.0196
# Epoch 11/23
# Learning Rate:  tf.Tensor(0.0015693402534231154, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0126 - val_loss: 0.0147
# Epoch 12/23
# Learning Rate:  tf.Tensor(0.0014464742787654269, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0118 - val_loss: 0.0148
# Epoch 13/23
# Learning Rate:  tf.Tensor(0.0013236083041077383, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0106 - val_loss: 0.0135
# Epoch 14/23
# Learning Rate:  tf.Tensor(0.0012007423294500498, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0089 - val_loss: 0.0136
# Epoch 15/23
# Learning Rate:  tf.Tensor(0.0010778763547923613, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0079 - val_loss: 0.0120
# Epoch 16/23
# Learning Rate:  tf.Tensor(0.0009550103801346727, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0069 - val_loss: 0.0118
# Epoch 17/23
# Learning Rate:  tf.Tensor(0.0008321444054769844, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0059 - val_loss: 0.0118
# Epoch 18/23
# Learning Rate:  tf.Tensor(0.0007092784308192959, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0053 - val_loss: 0.0120
# Epoch 19/23
# Learning Rate:  tf.Tensor(0.0005864124561616078, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0045 - val_loss: 0.0106
# Epoch 20/23
# Learning Rate:  tf.Tensor(0.0004635464815039192, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0034 - val_loss: 0.0103
# Epoch 21/23
# Learning Rate:  tf.Tensor(0.0003406805068462307, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0028 - val_loss: 0.0101
# Epoch 22/23
# Learning Rate:  tf.Tensor(0.00021781453218854213, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0024 - val_loss: 0.0102
# Epoch 23/23
# Learning Rate:  tf.Tensor(9.49485575308536e-05, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0021 - val_loss: 0.0102
# val4.csv val_performance = 0.01019559828371698
# val4.csv val accuracy = 0.96216
# array(['Walking', 'Walking', 'Upstair', ..., 'Jogging', 'Downstair',
#        'Jogging'], dtype='<U21')
# array(['Walking', 'Walking', 'Upstair', ..., 'Jogging', 'Downstair',
#        'Jogging'], dtype='<U21')
# Accuracy for each class is given below.
# Walking     : 98.37 %
# Jogging     : 98.78 %
# Sitting     : 98.72 %
# Standing    : 99.04 %
# Upstair     : 87.79 %
# Downstair   : 85.9 %
# float64
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# RNNp_layer (RNN)             (None, 81)                27216
# _________________________________________________________________
# MLP_layer (Dense)            (None, 9)                 738
# _________________________________________________________________
# Output_layer (Dense)         (None, 6)                 60
# =================================================================
# Total params: 28,014
# Trainable params: 28,014
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/23
# Learning Rate:  <tf.Variable 'lr:0' shape=() dtype=float64, numpy=0.002798>
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0407 - val_loss: 0.0230
# Epoch 2/23
# Learning Rate:  tf.Tensor(0.0026751340253423116, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0225 - val_loss: 0.0174
# Epoch 3/23
# Learning Rate:  tf.Tensor(0.002552268050684623, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0185 - val_loss: 0.0174
# Epoch 4/23
# Learning Rate:  tf.Tensor(0.0024294020760269345, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0165 - val_loss: 0.0182
# Epoch 5/23
# Learning Rate:  tf.Tensor(0.002306536101369246, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0149 - val_loss: 0.0140
# Epoch 6/23
# Learning Rate:  tf.Tensor(0.002183670126711558, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0141 - val_loss: 0.0133
# Epoch 7/23
# Learning Rate:  tf.Tensor(0.0020608041520538693, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0132 - val_loss: 0.0156
# Epoch 8/23
# Learning Rate:  tf.Tensor(0.0019379381773961808, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0124 - val_loss: 0.0197
# Epoch 9/23
# Learning Rate:  tf.Tensor(0.0018150722027384923, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0124 - val_loss: 0.0151
# Epoch 10/23
# Learning Rate:  tf.Tensor(0.001692206228080804, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0118 - val_loss: 0.0134
# Epoch 11/23
# Learning Rate:  tf.Tensor(0.0015693402534231154, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0101 - val_loss: 0.0142
# Epoch 12/23
# Learning Rate:  tf.Tensor(0.0014464742787654269, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0095 - val_loss: 0.0139
# Epoch 13/23
# Learning Rate:  tf.Tensor(0.0013236083041077383, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0086 - val_loss: 0.0116
# Epoch 14/23
# Learning Rate:  tf.Tensor(0.0012007423294500498, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0074 - val_loss: 0.0109
# Epoch 15/23
# Learning Rate:  tf.Tensor(0.0010778763547923613, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0065 - val_loss: 0.0109
# Epoch 16/23
# Learning Rate:  tf.Tensor(0.0009550103801346727, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0053 - val_loss: 0.0101
# Epoch 17/23
# Learning Rate:  tf.Tensor(0.0008321444054769844, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0049 - val_loss: 0.0101
# Epoch 18/23
# Learning Rate:  tf.Tensor(0.0007092784308192959, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0040 - val_loss: 0.0095
# Epoch 19/23
# Learning Rate:  tf.Tensor(0.0005864124561616078, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0033 - val_loss: 0.0092
# Epoch 20/23
# Learning Rate:  tf.Tensor(0.0004635464815039192, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0027 - val_loss: 0.0092
# Epoch 21/23
# Learning Rate:  tf.Tensor(0.0003406805068462307, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0022 - val_loss: 0.0088
# Epoch 22/23
# Learning Rate:  tf.Tensor(0.00021781453218854213, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0020 - val_loss: 0.0087
# Epoch 23/23
# Learning Rate:  tf.Tensor(9.49485575308536e-05, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0018 - val_loss: 0.0088
# val5.csv val_performance = 0.00875220688682077
# val5.csv val accuracy = 0.96521
# array(['Walking', 'Sitting', 'Jogging', ..., 'Downstair', 'Jogging',
#        'Walking'], dtype='<U21')
# array(['Walking', 'Sitting', 'Jogging', ..., 'Downstair', 'Jogging',
#        'Walking'], dtype='<U21')
# Accuracy for each class is given below.
# Walking     : 98.44 %
# Jogging     : 98.28 %
# Sitting     : 98.38 %
# Standing    : 99.34 %
# Upstair     : 91.18 %
# Downstair   : 86.69 %
# float64
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# RNNp_layer (RNN)             (None, 81)                27216
# _________________________________________________________________
# MLP_layer (Dense)            (None, 9)                 738
# _________________________________________________________________
# Output_layer (Dense)         (None, 6)                 60
# =================================================================
# Total params: 28,014
# Trainable params: 28,014
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/23
# Learning Rate:  <tf.Variable 'lr:0' shape=() dtype=float64, numpy=0.002798>
# 3443/3443 [==============================] - 50s 14ms/step - loss: 0.0401 - val_loss: 0.0251
# Epoch 2/23
# Learning Rate:  tf.Tensor(0.0026751340253423116, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0213 - val_loss: 0.0162
# Epoch 3/23
# Learning Rate:  tf.Tensor(0.002552268050684623, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0162 - val_loss: 0.0187
# Epoch 4/23
# Learning Rate:  tf.Tensor(0.0024294020760269345, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0161 - val_loss: 0.0177
# Epoch 5/23
# Learning Rate:  tf.Tensor(0.002306536101369246, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0148 - val_loss: 0.0133
# Epoch 6/23
# Learning Rate:  tf.Tensor(0.002183670126711558, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0128 - val_loss: 0.0135
# Epoch 7/23
# Learning Rate:  tf.Tensor(0.0020608041520538693, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0119 - val_loss: 0.0139
# Epoch 8/23
# Learning Rate:  tf.Tensor(0.0019379381773961808, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0107 - val_loss: 0.0182
# Epoch 9/23
# Learning Rate:  tf.Tensor(0.0018150722027384923, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0104 - val_loss: 0.0132
# Epoch 10/23
# Learning Rate:  tf.Tensor(0.001692206228080804, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0091 - val_loss: 0.0125
# Epoch 11/23
# Learning Rate:  tf.Tensor(0.0015693402534231154, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0087 - val_loss: 0.0151
# Epoch 12/23
# Learning Rate:  tf.Tensor(0.0014464742787654269, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0075 - val_loss: 0.0126
# Epoch 13/23
# Learning Rate:  tf.Tensor(0.0013236083041077383, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0073 - val_loss: 0.0106
# Epoch 14/23
# Learning Rate:  tf.Tensor(0.0012007423294500498, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0058 - val_loss: 0.0099
# Epoch 15/23
# Learning Rate:  tf.Tensor(0.0010778763547923613, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0056 - val_loss: 0.0102
# Epoch 16/23
# Learning Rate:  tf.Tensor(0.0009550103801346727, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0049 - val_loss: 0.0097
# Epoch 17/23
# Learning Rate:  tf.Tensor(0.0008321444054769844, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0038 - val_loss: 0.0100
# Epoch 18/23
# Learning Rate:  tf.Tensor(0.0007092784308192959, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0031 - val_loss: 0.0089
# Epoch 19/23
# Learning Rate:  tf.Tensor(0.0005864124561616078, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0024 - val_loss: 0.0086
# Epoch 20/23
# Learning Rate:  tf.Tensor(0.0004635464815039192, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0019 - val_loss: 0.0084
# Epoch 21/23
# Learning Rate:  tf.Tensor(0.0003406805068462307, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0016 - val_loss: 0.0085
# Epoch 22/23
# Learning Rate:  tf.Tensor(0.00021781453218854213, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0014 - val_loss: 0.0084
# Epoch 23/23
# Learning Rate:  tf.Tensor(9.49485575308536e-05, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0014 - val_loss: 0.0084
# val6.csv val_performance = 0.008377085395578179
# val6.csv val accuracy = 0.96855
# array(['Downstair', 'Upstair', 'Jogging', ..., 'Jogging', 'Upstair',
#        'Jogging'], dtype='<U21')
# array(['Downstair', 'Downstair', 'Jogging', ..., 'Jogging', 'Upstair',
#        'Jogging'], dtype='<U21')
# Accuracy for each class is given below.
# Walking     : 98.63 %
# Jogging     : 99.01 %
# Sitting     : 99.02 %
# Standing    : 99.36 %
# Upstair     : 90.68 %
# Downstair   : 87.17 %
# float64
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# RNNp_layer (RNN)             (None, 81)                27216
# _________________________________________________________________
# MLP_layer (Dense)            (None, 9)                 738
# _________________________________________________________________
# Output_layer (Dense)         (None, 6)                 60
# =================================================================
# Total params: 28,014
# Trainable params: 28,014
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/23
# Learning Rate:  <tf.Variable 'lr:0' shape=() dtype=float64, numpy=0.002798>
# 3443/3443 [==============================] - 49s 14ms/step - loss: 0.0429 - val_loss: 0.0267
# Epoch 2/23
# Learning Rate:  tf.Tensor(0.0026751340253423116, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0230 - val_loss: 0.0257
# Epoch 3/23
# Learning Rate:  tf.Tensor(0.002552268050684623, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0200 - val_loss: 0.0247
# Epoch 4/23
# Learning Rate:  tf.Tensor(0.0024294020760269345, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0182 - val_loss: 0.0214
# Epoch 5/23
# Learning Rate:  tf.Tensor(0.002306536101369246, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0167 - val_loss: 0.0184
# Epoch 6/23
# Learning Rate:  tf.Tensor(0.002183670126711558, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0158 - val_loss: 0.0200
# Epoch 7/23
# Learning Rate:  tf.Tensor(0.0020608041520538693, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0146 - val_loss: 0.0170
# Epoch 8/23
# Learning Rate:  tf.Tensor(0.0019379381773961808, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0138 - val_loss: 0.0152
# Epoch 9/23
# Learning Rate:  tf.Tensor(0.0018150722027384923, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0135 - val_loss: 0.0162
# Epoch 10/23
# Learning Rate:  tf.Tensor(0.001692206228080804, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0132 - val_loss: 0.0149
# Epoch 11/23
# Learning Rate:  tf.Tensor(0.0015693402534231154, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0114 - val_loss: 0.0126
# Epoch 12/23
# Learning Rate:  tf.Tensor(0.0014464742787654269, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0098 - val_loss: 0.0125
# Epoch 13/23
# Learning Rate:  tf.Tensor(0.0013236083041077383, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0090 - val_loss: 0.0121
# Epoch 14/23
# Learning Rate:  tf.Tensor(0.0012007423294500498, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0075 - val_loss: 0.0114
# Epoch 15/23
# Learning Rate:  tf.Tensor(0.0010778763547923613, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0064 - val_loss: 0.0117
# Epoch 16/23
# Learning Rate:  tf.Tensor(0.0009550103801346727, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0063 - val_loss: 0.0104
# Epoch 17/23
# Learning Rate:  tf.Tensor(0.0008321444054769844, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0052 - val_loss: 0.0098
# Epoch 18/23
# Learning Rate:  tf.Tensor(0.0007092784308192959, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0044 - val_loss: 0.0097
# Epoch 19/23
# Learning Rate:  tf.Tensor(0.0005864124561616078, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0034 - val_loss: 0.0098
# Epoch 20/23
# Learning Rate:  tf.Tensor(0.0004635464815039192, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0029 - val_loss: 0.0096
# Epoch 21/23
# Learning Rate:  tf.Tensor(0.0003406805068462307, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0023 - val_loss: 0.0093
# Epoch 22/23
# Learning Rate:  tf.Tensor(0.00021781453218854213, shape=(), dtype=float64)
# 3443/3443 [==============================] - 47s 14ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 23/23
# Learning Rate:  tf.Tensor(9.49485575308536e-05, shape=(), dtype=float64)
# 3443/3443 [==============================] - 48s 14ms/step - loss: 0.0018 - val_loss: 0.0092
# val7.csv val_performance = 0.009183635614601423
# val7.csv val accuracy = 0.96608
# array(['Jogging', 'Downstair', 'Walking', ..., 'Jogging', 'Jogging',
#        'Upstair'], dtype='<U21')
# array(['Jogging', 'Downstair', 'Walking', ..., 'Jogging', 'Jogging',
#        'Upstair'], dtype='<U21')
# Accuracy for each class is given below.
# Walking     : 98.84 %
# Jogging     : 99.0 %
# Sitting     : 98.03 %
# Standing    : 98.76 %
# Upstair     : 86.93 %
# Downstair   : 88.92 %

# %%
def plot_cms(cMs, labels, titles, cols):
    total = len(cMs)
    rows = math.ceil(total/cols)
    np.random.seed(19680801)
    fig, axs = plt.subplots(rows, cols)
    
    for row in range(rows):
        for col in range(cols):
            ax = axs[row, col]
            if (rows*row+col) + 1 > total:
                break
            cM = cMs[rows*row+col]
            cmNormalized = np.around((cM/cM.sum(axis=1)[:,None])*100,2)
            icm = plt.imshow(cmNormalized,interpolation=None,cmap = plt.cm.Blues)
            fig.colorbar(icm, ax=ax)
    plt.show
