# %% [markdown]
# ## Merging results of RNN plus networks

# %%
import os, sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def plotFunction(data, title):
    # Fixing random state for reproducibility
    np.random.seed(19680801)
    plt.rcdefaults()
    fig, ax = plt.subplots()

    # Example data
    ax.barh(data.index, data.values, align='center')
    ax.set_yticks(data.index)
    ax.set_yticklabels(data.index)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('Number of Dataset')
    ax.set_title(title)

    for i, v in enumerate(data.values):
        ax.text(v + 0.5, i +0.05, str(v), color='black', fontweight='bold')
    plt.show()
    
results_dir_i = "./results/2_rnn_plus/rnn_plus_v1_15112021_ES_DS_UnRolled/"
results_dir_o = "./results/2_rnn_plus/rnn_plus_v1_15112021_ES_DS_UnRolled_merged/"
results_list = sorted(os.listdir(results_dir_i))[1:]
merged_results = None
count = -1
prefix = 'RNN_plus_v1' #'mse'

if not os.path.exists(results_dir_o):
    os.makedirs(results_dir_o)
    
with open('valacc.mse.txt') as f:
    lines = ([line.replace('\n', '').split(' ')[3:6:2] for line in f.readlines()[5:] if line.strip('\n')])

for line in lines:
    count = count + 1 if count < 2 else 0
    fn = line[0].split('/')[2].split('.')
    fn_i = f"{prefix}_{fn[1].split('=')[-1]}_{fn[2].split('=')[-1]}_{fn[3].split('=')[-1]}_{fn[4].split('s')[-1]}_{fn[5].split('n')[-1]}_{fn[6]}.csv"
    fn_o = f"{prefix}_{fn[1].split('=')[-1]}_{fn[2].split('=')[-1]}_{fn[3].split('=')[-1]}_{fn[4].split('s')[-1]}_{fn[5].split('n')[-1]}_{fn[6]}_merged.csv"
    resultpath_i = results_dir_i + fn_i
    resultpath_o = results_dir_o + fn_o
    if not os.path.exists(resultpath_o):
        result = pd.read_csv(resultpath_i, index_col=0)
    else:
        result = pd.read_csv(resultpath_o, index_col=0)
        
    result.loc[f'olstm_{count}'] = round(float(line[1]),5)
    result.to_csv(resultpath_o, index=True)

for results_item in sorted(os.listdir(results_dir_o)):
    resultpath = results_dir_o + results_item
    result = pd.read_csv(resultpath, index_col=0)
    rnnplus_avg = float(result.loc['rnnplus_avg'].values[0])
    olstm_avg = sum([float(result.loc['olstm_0'].values[0]), float(result.loc['olstm_1'].values[0]), float(result.loc['olstm_2'].values[0])])/3.0
    delta = (rnnplus_avg - olstm_avg)
    if delta > 0.01:
        delta_bool = 'better'
    elif delta < -0.01:
        delta_bool = 'worse'
    else:
        delta_bool = 'same'
    result = result.drop(labels=['olstm_0', 'olstm_1', 'olstm_2'], axis=0)
    result.loc[f'olstm_avg'] = round(olstm_avg,6)
    result.loc[f'delta'] = round(delta, 6)
    result.loc[f'isbetter'] = delta_bool
    result.to_csv(resultpath, index=True)
    
for results_item in sorted(os.listdir(results_dir_o)):
    resultpath = results_dir_o + results_item
    result = pd.read_csv(resultpath, index_col=0)
    merged_results = result if merged_results is None else pd.concat([merged_results, result], axis=1)

# merged_results = merged_results.drop(index='tuner/trial_id')
merged_results.to_csv(results_dir_o + 'rnn_plus_v1_30112021_ES_DS_UnRolled_LS_mergedresult.csv', index=True)

isbetter_pd = merged_results.T.groupby(['isbetter']).count()['dataset_no'].sort_values(ascending=False)
print(f'++ Number of isBetter: \033[1m{isbetter_pd.index[0]}\033[0m with \033[1m{isbetter_pd[0]}\033[0m/180')
print(f'++ Number of isBetter: \033[1m{isbetter_pd.index[1]}\033[0m with \033[1m{isbetter_pd[1]}\033[0m/180')
print(f'++ Number of isBetter: \033[1m{isbetter_pd.index[2]}\033[0m with \033[1m{isbetter_pd[2]}\033[0m/180')

# %%
import os, sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def plotFunction(data, title):
    # Fixing random state for reproducibility
    np.random.seed(19680801)
    plt.rcdefaults()
    fig, ax = plt.subplots()

    # Example data
    ax.barh(data.index, data.values, align='center')
    ax.set_yticks(data.index)
    ax.set_yticklabels(data.index)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('Number of Dataset')
    ax.set_title(title)

    for i, v in enumerate(data.values):
        ax.text(v + 0.5, i +0.05, str(v), color='black', fontweight='bold')
    plt.show()
    
results_dir_i = "./results/2_rnn_plus/rnn_plus_v1_15112021_ES_DS_UnRolled/"
results_dir_o = "./results/2_rnn_plus/rnn_plus_v1_15112021_ES_DS_UnRolled_merged_1/"
results_list = sorted(os.listdir(results_dir_i))[1:]
merged_results = None
count = -1
prefix = 'RNN_plus_v1' #'mse'

if not os.path.exists(results_dir_o):
    os.makedirs(results_dir_o)
    
with open('valacc.mse.txt') as f:
    lines = ([line.replace('\n', '').split(' ')[3:6:2] for line in f.readlines()[5:] if line.strip('\n')])

for line in lines:
    count = count + 1 if count < 2 else 0
    fn = line[0].split('/')[2].split('.')
    fn_i = f"{prefix}_{fn[1].split('=')[-1]}_{fn[2].split('=')[-1]}_{fn[3].split('=')[-1]}_{fn[4].split('s')[-1]}_{fn[5].split('n')[-1]}_{fn[6]}.csv"
    fn_o = f"{prefix}_{fn[1].split('=')[-1]}_{fn[2].split('=')[-1]}_{fn[3].split('=')[-1]}_{fn[4].split('s')[-1]}_{fn[5].split('n')[-1]}_{fn[6]}_merged.csv"
    resultpath_i = results_dir_i + fn_i
    resultpath_o = results_dir_o + fn_o
    if not os.path.exists(resultpath_o):
        result = pd.read_csv(resultpath_i, index_col=0)
    else:
        result = pd.read_csv(resultpath_o, index_col=0)
        
    result.loc[f'olstm_{count}'] = round(float(line[1]),5)
    result.to_csv(resultpath_o, index=True)

for results_item in sorted(os.listdir(results_dir_o)):
    resultpath = results_dir_o + results_item
    result = pd.read_csv(resultpath, index_col=0)
    rnnplus_avg = float(result.loc['accuracy_avg'].values[0])
    olstm_avg = sum([float(result.loc['olstm_0'].values[0]), float(result.loc['olstm_1'].values[0]), float(result.loc['olstm_2'].values[0])])/3.0
    delta = (rnnplus_avg - olstm_avg)
    if delta > 0.01:
        delta_bool = 'better'
    elif delta < -0.01:
        delta_bool = 'worse'
    else:
        delta_bool = 'same'
    result = result.drop(labels=['olstm_0', 'olstm_1', 'olstm_2'], axis=0)
    result.loc[f'olstm_avg'] = round(olstm_avg,6)
    result.loc[f'delta'] = round(delta, 6)
    result.loc[f'isbetter'] = delta_bool
    result.to_csv(resultpath, index=True)
    
for results_item in sorted(os.listdir(results_dir_o)):
    resultpath = results_dir_o + results_item
    result = pd.read_csv(resultpath, index_col=0)
    merged_results = result if merged_results is None else pd.concat([merged_results, result], axis=1)

# merged_results = merged_results.drop(index='tuner/trial_id')
merged_results.to_csv(results_dir_o + 'RNN_plus_v1_15112021_ES_DS_UnRolled_mergedresult.csv', index=True)

isbetter_pd = merged_results.T.groupby(['isbetter']).count()['dataset_no'].sort_values(ascending=False)
print(f'++ Number of isBetter: \033[1m{isbetter_pd.index[0]}\033[0m with \033[1m{isbetter_pd[0]}\033[0m/180')
print(f'++ Number of isBetter: \033[1m{isbetter_pd.index[1]}\033[0m with \033[1m{isbetter_pd[1]}\033[0m/180')
print(f'++ Number of isBetter: \033[1m{isbetter_pd.index[2]}\033[0m with \033[1m{isbetter_pd[2]}\033[0m/180')

# %%
with open('chautran1.evals') as f:
    # lines = ([line.replace('\n', '').split(' ')[3:6:2] for line in f.readlines()[5:] if line.strip('\n')])
    lines = [line.replace('\n','').split(' ')[2:5:2] for line in f.readlines()]

for line in lines:
    fn = line[0].split('/')[1].split('.')
    fn_i = f"{prefix}_{fn[1].split('=')[-1]}_{fn[2].split('=')[-1]}_{fn[3].split('=')[-1]}_{fn[4].split('s')[-1]}_{fn[5].split('n')[-1]}_{fn[6]}.csv"
    fn_o = f"{prefix}_{fn[1].split('=')[-1]}_{fn[2].split('=')[-1]}_{fn[3].split('=')[-1]}_{fn[4].split('s')[-1]}_{fn[5].split('n')[-1]}_{fn[6]}_merged.csv"
    # resultpath_i = results_dir_i + fn_i
    # resultpath_o = results_dir_o + fn_o
    # if not os.path.exists(resultpath_o):
    #     result = pd.read_csv(resultpath_i, index_col=0)
    # else:
    #     result = pd.read_csv(resultpath_o, index_col=0)
        
    print(fn_i)
    sys.exit()

# %%
import os, sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

prefix = '28122021'
path = f"./results/2_rnn_plus/{prefix}"
results_list = sorted(os.listdir(path))

results_pd = pd.DataFrame()
results_dict = {}
count = 0
for result in results_list:
    result_pd = (pd.read_csv(path + "/" + result, header=None, index_col=0))
    if f'{result.split("f")[0]}f' in results_dict.keys():
        results_dict[f'{result.split("f")[0]}f'][result_pd.loc[f'dataset_name'].values[0].split('/')[-1]] = result_pd.loc[f'accuracy_avg'].values[0]
    else:
        results_dict[f'{result.split("f")[0]}f'] = {result_pd.loc[f'dataset_name'].values[0].split('/')[-1]: result_pd.loc[f'accuracy_avg'].values[0]}

for test in results_dict.keys():
    results_pd = pd.concat([results_pd, pd.DataFrame(data=results_dict[test].values(), index=results_dict[test].keys(), columns=[str(test)])], axis=1)
display(results_pd)
results_pd.to_csv(f"./results/3_mergeResults/{prefix}_merge_results_5bigdatasets.csv", index=True, index_label='dataset', mode='w')
# Out:
#                                                    lstm_wLRS_wCMF_tf  \
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...           77.4432
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv           87.7844
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv           81.6888
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv           78.0948
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...           80.9994
#
#                                                    lstm_wLRS_wtCMF_tf  \
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...            79.8544
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv             89.601
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv            82.5512
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv            77.9632
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...            80.8718
#
#                                                    lstm_wtLRS_wCMF_tf  \
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...            77.2614
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv            87.6564
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv            81.4258
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv            77.6428
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...            80.4736
#
#                                                    lstm_wtLRS_wtCMF_tf  \
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...             77.6418
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv               86.33
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv              81.311
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv             77.4606
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...             80.6426
#
#                                                    rnn_plus_wLRS_wCMF_tf  \
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...               76.5922
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv               86.4996
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv               82.2842
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv               79.2492
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...                80.437
#
#                                                    rnn_plus_wLRS_wtCMF_tf  \
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...                81.2998
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv                86.8418
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv                 82.414
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv                78.5956
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...                80.3684
#
#                                                    rnn_plus_wtLRS_wCMF_tf  \
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...                  79.31
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv                87.2968
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv                79.4948
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv                77.5564
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...                80.3294
#
#                                                    rnn_plus_wtLRS_wtCMF_tf  \
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...                    77.3
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv                 86.1586
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv                 80.2844
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv                 77.8658
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...                 78.7056
#
#                                                    rnn_wLRS_wCMF_tf  \
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...           78.978
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv            86.11
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv           81.221
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv          78.2436
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...          78.6564
#
#                                                    rnn_wLRS_wtCMF_tf  \
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...           76.6766
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv            86.589
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv           81.6778
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv           77.5912
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...           78.5072
#
#                                                    rnn_wtLRS_wCMF_tf  \
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...           78.0306
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv           86.1878
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv           80.8746
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv           77.6774
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...           80.5446
#
#                                                    rnn_wtLRS_wtCMF_tf
# seqnetdata.ni=14.no=19.mc=221.numTimeSteps300.5...            75.9748
# seqnetdata.ni=15.no=22.mc=44.numTimeSteps84.60.csv            86.3844
# seqnetdata.ni=20.no=24.mc=69.numTimeSteps71.85.csv             79.974
# seqnetdata.ni=23.no=27.mc=52.numTimeSteps80.51.csv            77.1536
# seqnetdata.ni=27.no=32.mc=63.numTimeSteps125.32...            79.0458
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12072/53511222.py in <module>
#      21     results_pd = pd.concat([results_pd, pd.DataFrame(data=results_dict[test].values(), index=results_dict[test].keys(), columns=[str(test)])], axis=1)
#      22 display(results_pd)
# ---> 23 results_pd.to_csv(f"./results/3_mergeResults/{prefix}_merge_results_5bigdatasets.csv", index=True, index_label='dataset', mode='w')
#
# ~\Anaconda3\envs\master_thesis\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\Anaconda3\envs\master_thesis\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\Anaconda3\envs\master_thesis\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\Anaconda3\envs\master_thesis\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: './results/3_mergeResults/28122021_merge_results_5bigdatasets.csv'
